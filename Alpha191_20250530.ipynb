# %% [markdown]
# ### 1. Load History OHCLV
#
# create a new terminal and
#
# Download-data:
# `
# freqtrade download-data --config user_data/config.json --timeframe 15m --timerange 20240101-20250101
# `
#
# File-like:
# `
# BTC_USDT-15m.feather
# `

# %%
import pandas as pd 
import os
import re
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.append('./')

file_path = '/usr/local/services/freqtrade-grid/user_data/data/binance/futures'
time_frame = '1d'

def extract_coin_symbols(directory):
    coin_list = []
    pattern = re.compile(r'(.+?)_USDT-1d-futures\.feather$')

    for filename in os.listdir(directory):
        match = pattern.match(filename)
        if match:
            coin_symbol = (match.group(1)+':USDT').replace('_','/')
            coin_list.append(coin_symbol)
    
    return coin_list


if os.path.exists(file_path) and os.path.isdir(file_path):
    coins = extract_coin_symbols(file_path)
print(len(coins))
# Out:
# 393

# %% [markdown]
# ### 2. Pair Filter

# %%
top50 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT"
]

top100 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT","ATOM/USDT:USDT","ALGO/USDT:USDT","JUP/USDT:USDT","TIA/USDT:USDT","VIRTUAL/USDT:USDT","INJ/USDT:USDT","QNT/USDT:USDT","STX/USDT:USDT","S/USDT:USDT","DEXE/USDT:USDT","OP/USDT:USDT","FARTCOIN/USDT:USDT","IP/USDT:USDT","FORM/USDT:USDT","SEI/USDT:USDT","A/USDT:USDT","SPX/USDT:USDT","IMX/USDT:USDT","WIF/USDT:USDT","GRT/USDT:USDT","CRV/USDT:USDT","LDO/USDT:USDT","ZEC/USDT:USDT","ENS/USDT:USDT","JASMY/USDT:USDT","THETA/USDT:USDT","CAKE/USDT:USDT","GALA/USDT:USDT","WAL/USDT:USDT","SAND/USDT:USDT","IOTA/USDT:USDT","PYTH/USDT:USDT","PENGU/USDT:USDT","BSV/USDT:USDT","PENDLE/USDT:USDT","KAIA/USDT:USDT"
]

top150 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT","ATOM/USDT:USDT","ALGO/USDT:USDT","JUP/USDT:USDT","TIA/USDT:USDT","VIRTUAL/USDT:USDT","INJ/USDT:USDT","QNT/USDT:USDT","STX/USDT:USDT","S/USDT:USDT","DEXE/USDT:USDT","OP/USDT:USDT","FARTCOIN/USDT:USDT","IP/USDT:USDT","FORM/USDT:USDT","SEI/USDT:USDT","A/USDT:USDT","SPX/USDT:USDT","IMX/USDT:USDT","WIF/USDT:USDT","GRT/USDT:USDT","CRV/USDT:USDT","LDO/USDT:USDT","ZEC/USDT:USDT","ENS/USDT:USDT","JASMY/USDT:USDT","THETA/USDT:USDT","CAKE/USDT:USDT","GALA/USDT:USDT","WAL/USDT:USDT","SAND/USDT:USDT","IOTA/USDT:USDT","PYTH/USDT:USDT","PENGU/USDT:USDT","BSV/USDT:USDT","PENDLE/USDT:USDT","KAIA/USDT:USDT","XTZ/USDT:USDT","RUNE/USDT:USDT","FLOW/USDT:USDT","BRETT/USDT:USDT","ZKJ/USDT:USDT","JTO/USDT:USDT","XCN/USDT:USDT","MANA/USDT:USDT","APE/USDT:USDT","KAITO/USDT:USDT","DEEP/USDT:USDT","ATH/USDT:USDT","GRASS/USDT:USDT","EIGEN/USDT:USDT","EGLD/USDT:USDT","DYDX/USDT:USDT","AR/USDT:USDT","AERO/USDT:USDT","STRK/USDT:USDT","KAVA/USDT:USDT","NEO/USDT:USDT","AXS/USDT:USDT","RSR/USDT:USDT","SUPER/USDT:USDT","LPT/USDT:USDT","ETHFI/USDT:USDT","W/USDT:USDT","CFX/USDT:USDT","SYRUP/USDT:USDT","CHZ/USDT:USDT","MOVE/USDT:USDT","POPCAT/USDT:USDT","MORPHO/USDT:USDT","COMP/USDT:USDT","SAFE/USDT:USDT","SUN/USDT:USDT"
]

top200 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT","ATOM/USDT:USDT","ALGO/USDT:USDT","JUP/USDT:USDT","TIA/USDT:USDT","VIRTUAL/USDT:USDT","INJ/USDT:USDT","QNT/USDT:USDT","STX/USDT:USDT","S/USDT:USDT","DEXE/USDT:USDT","OP/USDT:USDT","FARTCOIN/USDT:USDT","IP/USDT:USDT","FORM/USDT:USDT","SEI/USDT:USDT","A/USDT:USDT","SPX/USDT:USDT","IMX/USDT:USDT","WIF/USDT:USDT","GRT/USDT:USDT","CRV/USDT:USDT","LDO/USDT:USDT","ZEC/USDT:USDT","ENS/USDT:USDT","JASMY/USDT:USDT","THETA/USDT:USDT","CAKE/USDT:USDT","GALA/USDT:USDT","WAL/USDT:USDT","SAND/USDT:USDT","IOTA/USDT:USDT","PYTH/USDT:USDT","PENGU/USDT:USDT","BSV/USDT:USDT","PENDLE/USDT:USDT","KAIA/USDT:USDT","XTZ/USDT:USDT","RUNE/USDT:USDT","FLOW/USDT:USDT","BRETT/USDT:USDT","ZKJ/USDT:USDT","JTO/USDT:USDT","XCN/USDT:USDT","MANA/USDT:USDT","APE/USDT:USDT","KAITO/USDT:USDT","DEEP/USDT:USDT","ATH/USDT:USDT","GRASS/USDT:USDT","EIGEN/USDT:USDT","EGLD/USDT:USDT","DYDX/USDT:USDT","AR/USDT:USDT","AERO/USDT:USDT","STRK/USDT:USDT","KAVA/USDT:USDT","NEO/USDT:USDT","AXS/USDT:USDT","RSR/USDT:USDT","SUPER/USDT:USDT","LPT/USDT:USDT","ETHFI/USDT:USDT","W/USDT:USDT","CFX/USDT:USDT","SYRUP/USDT:USDT","CHZ/USDT:USDT","MOVE/USDT:USDT","POPCAT/USDT:USDT","MORPHO/USDT:USDT","COMP/USDT:USDT","SAFE/USDT:USDT","SUN/USDT:USDT","TWT/USDT:USDT","JST/USDT:USDT","AKT/USDT:USDT","OM/USDT:USDT","AXL/USDT:USDT","TURBO/USDT:USDT","BERA/USDT:USDT","1INCH/USDT:USDT","MEW/USDT:USDT","MINA/USDT:USDT","KSM/USDT:USDT","AI16Z/USDT:USDT","DASH/USDT:USDT","PNUT/USDT:USDT","ZRO/USDT:USDT","NXPC/USDT:USDT","SFP/USDT:USDT","NOT/USDT:USDT","SNX/USDT:USDT","GLM/USDT:USDT","ROSE/USDT:USDT","ZIL/USDT:USDT","MOCA/USDT:USDT","MASK/USDT:USDT","BLUR/USDT:USDT","QTUM/USDT:USDT","CKB/USDT:USDT","MOODENG/USDT:USDT","ASTR/USDT:USDT","ZK/USDT:USDT","ZRX/USDT:USDT","GAS/USDT:USDT","ORDI/USDT:USDT","BAT/USDT:USDT","VANA/USDT:USDT","ACH/USDT:USDT"
]

target_coins = coins
# print(target_coins)

# %% [markdown]
# ### 3. Load History OHLCV

# %%
def extract_coin_data(directory):
    coin_list = {}
    symbols = []
    pattern = re.compile(r'(.+?)_USDT-1d-futures\.feather$')

    for filename in os.listdir(directory):
        match = pattern.match(filename)
        if match:
            coin_symbol = (match.group(1)+':USDT').replace('_','/')
            if coin_symbol in target_coins: 
                df = pd.read_feather(f'{directory}/{filename}')
                df = df.reset_index(drop=True)
                if len(df) > 0 :
                    coin_list[coin_symbol] = df
                    symbols.append(coin_symbol)
    
    return coin_list,symbols

if os.path.exists(file_path) and os.path.isdir(file_path):
    coins,symbols = extract_coin_data(file_path)
print(len(coins))
# Out:
# 393

# %% [markdown]
# ### 3. History Data Transform

# %%
import pandas as pd
close_dfs = []
open_dfs = []
high_dfs = []
low_dfs = []
volume_dfs = []


for symbol, df in coins.items():
    
    temp_df = df[['date', 'close']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    close_dfs.append(temp_df)



    temp_df = df[['date', 'open']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    open_dfs.append(temp_df)


    temp_df = df[['date', 'high']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    high_dfs.append(temp_df)
    

    temp_df = df[['date', 'low']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    low_dfs.append(temp_df)

    temp_df = df[['date', 'volume']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    volume_dfs.append(temp_df)



close = pd.concat(close_dfs, axis=1)
open = pd.concat(open_dfs, axis=1)
high = pd.concat(high_dfs, axis=1)
low = pd.concat(low_dfs, axis=1)
volume = pd.concat(volume_dfs, axis=1)
amount = close.mul(volume, fill_value=1)
vwap = (high + low + close + open) / 4

# %% [markdown]
# ### 4. OHLCV Filter

# %%
start_time = '2024-06-01'
end_time = '2025-06-01'
close_filter = close[(close.index > start_time) & (close.index < end_time)]
open_filter = open[(open.index > start_time) & (open.index < end_time)]
high_filter = high[(high.index > start_time) & (high.index < end_time)]
low_filter = low[(low.index > start_time) & (low.index < end_time)]
volume_filter = volume[(volume.index > start_time) & (volume.index < end_time)]
amount_filter = amount[(amount.index > start_time) & (amount.index < end_time)]
vwap_filter = vwap[(vwap.index > start_time) & (vwap.index < end_time)]
benchmark_open_filter = open_filter.mean(axis=1)
benchmark_close_filter = close_filter.mean(axis=1)


import matplotlib.pyplot as plt
_, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))
high_norm = high_filter/high_filter.bfill().iloc[0] 
close_norm = close_filter/close_filter.bfill().iloc[0] 
high_norm.mean(axis=1).plot(ax=ax1, figsize=(15,6),grid=True)
close_norm.mean(axis=1).plot(ax=ax2, figsize=(15,6),grid=True);

# %% [markdown]
# ### 5. Define Factor

# %%
# Factor in WorldQuant 101
import Alpha191 as alpha191

df_data = {
    'open' : open_filter,
    'close' : close_filter,
    'high' : high_filter,
    'low' : low_filter,
    'volume' : volume_filter, 
    'vwap' : vwap_filter,
    'amount': amount_filter,
    'benchmark_open': benchmark_open_filter,
    'benchmark_close': benchmark_close_filter
}

alpha_all_in_one = alpha191.Alphas191(df_data)
alpha_list = [f"alpha{num:03d}" for num in range(1, 192)]

# %% [markdown]
# ### 6. Data transfrom and process

# %%
import alphalens.utils as utils
import alphalens.tears as tears
import alphalens.performance as perf
import alphalens.plotting as plot
import numpy as np

IC_tables = []
SP_tables = []


for alpha_name in alpha_list:
    try:
        method = getattr(alpha_all_in_one, alpha_name)
        single_alpha = method() 
        factor = single_alpha.stack()
        factor.index.names = ['date', 'asset']
        factor = factor.dropna()  # 清理缺失值
        price = close_filter
    
        factor_data = utils.get_clean_factor_and_forward_returns(
            factor=factor,
            prices=price,
            periods=(1,),  
            quantiles = 10
        )
        
        IC = perf.factor_information_coefficient(factor_data)
        IC_table = plot.plot_information_table(IC,return_df=True)
        IC_table['AlphaName'] = alpha_name
        IC_tables.append(IC_table)
        print(f'{alpha_name} done \n {IC_table}')



        mean_return_by_q, _ = perf.mean_return_by_quantile(
            factor_data,
            by_date=True, 
            demeaned=False,
            group_adjust=False
        )
        top_quantile_daily = mean_return_by_q.loc[10]  # 最高分组每日收益
        bottom_quantile_daily = mean_return_by_q.loc[1]  # 最低分组每日收益
        long_short_daily = top_quantile_daily - bottom_quantile_daily # 计算 Long-Short 组合（最高减最低）
        long_short_cumulative = perf.cumulative_returns(long_short_daily)
        mean_return = long_short_daily.mean()
        std_dev = long_short_daily.std()
        sharpe_ratio = (mean_return) / std_dev * np.sqrt(365)
        SP_table = pd.DataFrame([{
                    "AlphaName":alpha_name,
                    "SP":float(sharpe_ratio),
                    "Pro Daily Mean":float(mean_return),
                    "Pro Total":float(long_short_cumulative.iloc[-1])
                }])
        print(f'{alpha_name} done \n {SP_table}')
        SP_tables.append(SP_table)

       
        
        
    except:
        print(f'{alpha_name} error continue')
    

if len(IC_tables) > 0 :
    IC_df = pd.concat(IC_tables)
    IC_df.to_csv('ALPHA191_IC_tables.csv')

if len(SP_tables) > 0 :
    SP_df = pd.concat(SP_tables)
    SP_df.to_csv('ALPHA191_SP_tables.csv')
# Out:
# Dropped 22.5% entries from factor data: 22.3% in forward returns computation and 0.2% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha001 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)  IC Skew  \
# 1D  0.033754   0.0756          0.446479    8.435973  8.339859e-16 -0.00816
#
#     IC Kurtosis AlphaName
# 1D    -0.011941  alpha001
# alpha001 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha001  2.638905        0.001902   1.905244
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha002 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.026541  0.123427          0.215036    4.091341     0.000053  0.371469
#
#     IC Kurtosis AlphaName
# 1D     0.808213  alpha002
# alpha002 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha002  1.368398        0.001644   1.649288
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha003 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.001692  0.103494          -0.01635   -0.308919     0.757564  0.173341
#
#     IC Kurtosis AlphaName
# 1D     0.206778  alpha003
# alpha003 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha003  0.693884        0.000659   1.193177
# alpha004 error continue
# Dropped 30.8% entries from factor data: 22.3% in forward returns computation and 8.5% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha005 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.02187  0.092938           0.23532         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha005
# alpha005 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha005  0.118866        0.000097   0.992111
# Dropped 100.0% entries from factor data: 0.4% in forward returns computation and 99.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha006 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha007 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.006794  0.109352           0.06213    1.178829     0.239247  0.207729
#
#     IC Kurtosis AlphaName
# 1D     0.769509  alpha007
# alpha007 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha007 -0.229878       -0.000257   0.840126
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha008 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.005224  0.110375          0.047331    0.896801     0.370428  0.062893
#
#     IC Kurtosis AlphaName
# 1D     0.732353  alpha008
# alpha008 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha008 -0.527429       -0.000569    0.75555
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha009 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  -0.0088  0.110395         -0.079712   -1.516622     0.130237  0.15603
#
#     IC Kurtosis AlphaName
# 1D     0.028469  alpha009
# alpha009 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha009 -0.107822       -0.000106   0.903121
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha010 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.018818  0.156722          0.120075         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha010
# alpha010 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha010  1.259102        0.001013   1.361825
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha011 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.003827  0.144246          0.026532    0.502007     0.615972 -0.222717
#
#     IC Kurtosis AlphaName
# 1D     0.266252  alpha011
# alpha011 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha011  1.105352        0.001318   1.461004
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha012 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.003961   0.1065          0.037191     0.69974     0.484551 -0.24094
#
#     IC Kurtosis AlphaName
# 1D     0.157356  alpha012
# alpha012 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha012  0.025885        0.000025   0.948843
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha013 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.008845  0.101703         -0.086965   -1.656909     0.098404  0.030394
#
#     IC Kurtosis AlphaName
# 1D     0.169719  alpha013
# alpha013 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha013 -1.026217       -0.000957   0.667103
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha014 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.010656  0.110568         -0.096379   -1.823579     0.069052  0.059842
#
#     IC Kurtosis AlphaName
# 1D     0.503327  alpha014
# alpha014 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha014 -0.165336       -0.000184   0.863141
# Dropped 100.0% entries from factor data: 0.4% in forward returns computation and 99.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha015 error continue
# Dropped 23.2% entries from factor data: 22.1% in forward returns computation and 1.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha016 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.020448  0.06951           0.29417         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha016
# alpha016 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha016 -0.465583       -0.000348   0.855043
# Dropped 0.8% entries from factor data: 0.8% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha017 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.007911  0.106963          0.073956    1.381614     0.167977 -0.039987
#
#     IC Kurtosis AlphaName
# 1D      0.45249  alpha017
# alpha017 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha017 -0.054971       -0.000058    0.91395
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha018 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.029182  0.180145          -0.16199   -3.065002     0.002342 -0.170508
#
#     IC Kurtosis AlphaName
# 1D     0.635205  alpha018
# alpha018 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha018 -0.699496       -0.001167   0.548211
# alpha019 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha020 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.03306  0.182819         -0.180833    -3.41674     0.000707 -0.042131
#
#     IC Kurtosis AlphaName
# 1D     0.558045  alpha020
# alpha020 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha020 -0.84575       -0.001347   0.523667
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha021 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.014141  0.117578         -0.120272   -2.259708      0.02445  0.267338
#
#     IC Kurtosis AlphaName
# 1D    -0.022396  alpha021
# alpha021 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha021 -0.563196       -0.000581   0.760541
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha022 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.030825  0.164873          -0.18696   -3.522588     0.000483 -0.383029
#
#     IC Kurtosis AlphaName
# 1D     0.321845  alpha022
# alpha022 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha022 -0.871386       -0.001303   0.543891
# Dropped 1.1% entries from factor data: 0.4% in forward returns computation and 0.7% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha023 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.00057  0.144833         -0.003933   -0.072629     0.942144  0.035534
#
#     IC Kurtosis AlphaName
# 1D    -0.262199  alpha023
# alpha023 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha023 -0.347027       -0.000426   0.786943
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha024 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.013613  0.115353         -0.118009   -2.232839     0.026179  0.347645
#
#     IC Kurtosis AlphaName
# 1D     0.230157  alpha024
# alpha024 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha024 -0.558731       -0.000582   0.756578
# Dropped 1.0% entries from factor data: 1.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha025 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.007899  0.132903          0.059438    0.631832     0.528784  0.092022
#
#     IC Kurtosis AlphaName
# 1D     0.846951  alpha025
# alpha025 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha025  1.08106        0.001089   1.107997
# Dropped 0.8% entries from factor data: 0.8% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha026 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.034366  0.132493          0.259381     3.00255     0.003199 -0.31539
#
#     IC Kurtosis AlphaName
# 1D     0.513076  alpha026
# alpha026 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha026  1.027029        0.001314   1.145871
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha027 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.032692  0.194012         -0.168504   -3.134351      0.00187  0.230089
#
#     IC Kurtosis AlphaName
# 1D     0.258959  alpha027
# alpha027 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha027 -0.836985       -0.001361   0.528351
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha028 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.045857  0.14436         -0.317657   -5.985122  5.302348e-09  0.246767
#
#     IC Kurtosis AlphaName
# 1D     0.312792  alpha028
# alpha028 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha028 -1.228983       -0.001546   0.521227
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha029 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.020482  0.152115         -0.134647   -2.544087     0.011378  0.043179
#
#     IC Kurtosis AlphaName
# 1D    -0.149496  alpha029
# alpha029 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha029 -0.189599       -0.000269   0.797347
# alpha030 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha031 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.039681  0.194176         -0.204354   -3.834026     0.000149 -0.045842
#
#     IC Kurtosis AlphaName
# 1D     0.505468  alpha031
# alpha031 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha031 -1.188984        -0.00202   0.407367
# Dropped 22.4% entries from factor data: 22.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha032 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.026568  0.070638          0.376114    7.126341  5.714330e-12 -0.168552
#
#     IC Kurtosis AlphaName
# 1D     0.296431  alpha032
# alpha032 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha032  0.750697        0.000548   1.175614
# Dropped 0.9% entries from factor data: 0.9% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha033 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.005784  0.152471          0.037938    0.420755     0.674674  0.030617
#
#     IC Kurtosis AlphaName
# 1D    -0.357687  alpha033
# alpha033 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha033  1.93612        0.001936   1.240903
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha034 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.03968  0.194176          0.204353     3.83401     0.000149  0.045844
#
#     IC Kurtosis AlphaName
# 1D     0.505468  alpha034
# alpha034 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha034  1.183477         0.00201    1.68621
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha035 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.008412  0.098086          0.085766    1.583773     0.114175 -0.385809
#
#     IC Kurtosis AlphaName
# 1D     0.378027  alpha035
# alpha035 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha035  0.242443        0.000228   1.022696
# Dropped 22.9% entries from factor data: 22.9% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha036 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.024497  0.079966          -0.30635   -5.788312  1.561091e-08  0.027473
#
#     IC Kurtosis AlphaName
# 1D    -0.314622  alpha036
# alpha036 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha036  0.081429        0.000069   0.978405
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha037 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.014204  0.10576          0.134303    2.505383     0.012689  0.145198
#
#     IC Kurtosis AlphaName
# 1D     0.338084  alpha037
# alpha037 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha037  0.776179        0.000751   1.224147
# alpha038 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha039 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.006396  0.108318           0.05905    1.087219     0.277715 -0.062049
#
#     IC Kurtosis AlphaName
# 1D     0.448981  alpha039
# alpha039 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha039 -0.847095       -0.000827   0.712151
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha040 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.032611  0.121825         -0.267689   -4.921404     0.000001  0.227655
#
#     IC Kurtosis AlphaName
# 1D     0.215591  alpha040
# alpha040 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha040 -1.229615       -0.001348   0.588227
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha041 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.000507  0.120036          0.004224     0.07969     0.936529 -0.158239
#
#     IC Kurtosis AlphaName
# 1D    -0.212026  alpha041
# alpha041 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha041 -0.228521       -0.000245   0.851383
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha042 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.029324  0.104534          0.280525    5.278055  2.285123e-07 -0.128821
#
#     IC Kurtosis AlphaName
# 1D    -0.100593  alpha042
# alpha042 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha042  0.97093        0.000822   1.277105
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha043 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.025724  0.12843         -0.200295   -3.784461     0.000181 -0.063876
#
#     IC Kurtosis AlphaName
# 1D    -0.002596  alpha043
# alpha043 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha043 -1.390254       -0.001594   0.519282
# Dropped 93.9% entries from factor data: 0.4% in forward returns computation and 93.5% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha044 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha045 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.024033  0.111544         -0.215456   -4.025046      0.00007  0.121701
#
#     IC Kurtosis AlphaName
# 1D     0.572661  alpha045
# alpha045 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha045 -0.325091       -0.000316   0.843999
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha046 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.046274  0.200564          0.230719    4.254245     0.000027  0.053356
#
#     IC Kurtosis AlphaName
# 1D     0.460632  alpha046
# alpha046 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha046  1.400112         0.00236   1.869987
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha047 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.015373  0.169134         -0.090892   -1.719764     0.086342  0.096812
#
#     IC Kurtosis AlphaName
# 1D     0.587124  alpha047
# alpha047 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha047 -0.315917       -0.000469   0.731953
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha048 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.028953  0.114208          0.253513    4.701967     0.000004  0.183395
#
#     IC Kurtosis AlphaName
# 1D     0.266307  alpha048
# alpha048 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha048  1.405358        0.001449   1.539323
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha049 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.027145  0.142223          0.190864    3.575844     0.000398 -0.09445
#
#     IC Kurtosis AlphaName
# 1D     0.190047  alpha049
# alpha049 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha049  0.418759        0.000539   1.087003
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha050 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.027145  0.142223         -0.190861   -3.575773     0.000398  0.094435
#
#     IC Kurtosis AlphaName
# 1D     0.190047  alpha050
# alpha050 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha050 -0.418569       -0.000539   0.744358
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha051 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.027145  0.142223         -0.190863   -3.575808     0.000398  0.094443
#
#     IC Kurtosis AlphaName
# 1D     0.190053  alpha051
# alpha051 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha051 -0.418569       -0.000539   0.744358
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha052 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.036454  0.155137          -0.23498   -4.313667     0.000021  0.367347
#
#     IC Kurtosis AlphaName
# 1D     0.047137  alpha052
# alpha052 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha052 -0.555449       -0.000764   0.688046
# Dropped 100.0% entries from factor data: 22.0% in forward returns computation and 78.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha053 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha054 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.015887  0.11439         -0.138887   -2.613149     0.009355  0.066787
#
#     IC Kurtosis AlphaName
# 1D    -0.136811  alpha054
# alpha054 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha054 -2.404216       -0.002625   0.365268
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha055 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.014266  0.111448         -0.128005   -2.370679     0.018309  0.286446
#
#     IC Kurtosis AlphaName
# 1D    -0.094627  alpha055
# alpha055 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha055  0.129778        0.000119   0.988009
# alpha056 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha057 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.005104  0.163989         -0.031126   -0.586455     0.557943 -0.085882
#
#     IC Kurtosis AlphaName
# 1D     0.594611  alpha057
# alpha057 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha057 -0.404813       -0.000574    0.71562
# Dropped 100.0% entries from factor data: 21.6% in forward returns computation and 78.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha058 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha059 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.005409  0.137605          0.039304    0.727929     0.467155  0.130097
#
#     IC Kurtosis AlphaName
# 1D    -0.218321  alpha059
# alpha059 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha059  0.204019        0.000218   1.002985
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha060 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.004835  0.151839          0.031845    0.590644     0.555148 -0.071858
#
#     IC Kurtosis AlphaName
# 1D    -0.095877  alpha060
# alpha060 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha060  1.191121        0.001464   1.504799
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha061 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.003639  0.115816          0.031422    0.579393     0.562709 -0.204091
#
#     IC Kurtosis AlphaName
# 1D     0.213095  alpha061
# alpha061 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha061 -1.031683       -0.001066   0.651287
# Dropped 22.5% entries from factor data: 22.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha062 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.047052  0.090604           0.51932    9.839718  2.228715e-20 -0.139389
#
#     IC Kurtosis AlphaName
# 1D    -0.278892  alpha062
# alpha062 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha062  2.553519         0.00199    1.96211
# Dropped 1.0% entries from factor data: 0.4% in forward returns computation and 0.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha063 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)  IC Skew  \
# 1D -0.040571  0.14467         -0.280442   -5.313612  1.893713e-07  0.05491
#
#     IC Kurtosis AlphaName
# 1D     0.423242  alpha063
# alpha063 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha063 -0.263801       -0.000367   0.772351
# Dropped 36.5% entries from factor data: 36.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha064 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha065 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.03928  0.188014          0.208923    3.953002     0.000093  0.245449
#
#     IC Kurtosis AlphaName
# 1D      0.40125  alpha065
# alpha065 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha065  1.250841        0.002047   1.747268
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha066 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.03928  0.188014         -0.208922   -3.952993     0.000093 -0.245448
#
#     IC Kurtosis AlphaName
# 1D     0.401248  alpha066
# alpha066 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha066 -1.252659       -0.002049   0.402551
# Dropped 1.0% entries from factor data: 0.4% in forward returns computation and 0.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha067 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.021323  0.142211         -0.149937   -2.840893     0.004756  0.010443
#
#     IC Kurtosis AlphaName
# 1D     0.149334  alpha067
# alpha067 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha067 -0.423441       -0.000504   0.760832
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha068 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.010662  0.108931         -0.097874   -1.862173     0.063391  0.263085
#
#     IC Kurtosis AlphaName
# 1D     0.407087  alpha068
# alpha068 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha068 -0.473633       -0.000454   0.798384
# alpha069 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha070 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.061514  0.137071         -0.448771   -8.491151  5.577809e-16  0.099576
#
#     IC Kurtosis AlphaName
# 1D     0.061812  alpha070
# alpha070 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha070 -1.516545        -0.00181   0.476245
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha071 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.040442  0.205327         -0.196961    -3.63179     0.000325  0.059935
#
#     IC Kurtosis AlphaName
# 1D     0.407339  alpha071
# alpha071 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha071 -0.842876       -0.001447   0.508986
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha072 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.024514  0.175447         -0.139724   -2.643701     0.008562  0.174495
#
#     IC Kurtosis AlphaName
# 1D      0.41843  alpha072
# alpha072 done
#    AlphaName     SP  Pro Daily Mean  Pro Total
# 0  alpha072 -0.778       -0.001192   0.559767
# Dropped 21.1% entries from factor data: 20.9% in forward returns computation and 0.2% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha073 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.008165  0.090336          0.090385     1.64442     0.101042  0.005217
#
#     IC Kurtosis AlphaName
# 1D     0.442224  alpha073
# alpha073 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha073  1.208628        0.001009   1.339284
# Dropped 24.1% entries from factor data: 22.3% in forward returns computation and 1.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha074 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D -0.011529  0.087993         -0.131016         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha074
# alpha074 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha074  0.301089        0.000271   1.043556
# Dropped 100.0% entries from factor data: 100.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha075 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha076 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.022717  0.099023         -0.229415   -4.248823     0.000028  0.003313
#
#     IC Kurtosis AlphaName
# 1D    -0.353281  alpha076
# alpha076 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha076 -1.270231       -0.001079   0.660005
# Dropped 5.3% entries from factor data: 0.4% in forward returns computation and 5.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha077 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.029413  0.101581         -0.289549   -5.195772  3.631857e-07  0.043042
#
#     IC Kurtosis AlphaName
# 1D    -0.395183  alpha077
# alpha077 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha077 -0.99892        -0.00084   0.731844
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha078 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.037371  0.130833         -0.285639   -5.274668  2.372207e-07 -0.155613
#
#     IC Kurtosis AlphaName
# 1D     0.759875  alpha078
# alpha078 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha078 -0.195321        -0.00024   0.838336
# Dropped 1.0% entries from factor data: 0.4% in forward returns computation and 0.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha079 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.034878  0.148104         -0.235498   -4.462053     0.000011  0.089539
#
#     IC Kurtosis AlphaName
# 1D     0.259849  alpha079
# alpha079 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha079 -0.147415       -0.000198   0.827917
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha080 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.011355  0.109162         -0.104024   -1.968227     0.049815 -0.072833
#
#     IC Kurtosis AlphaName
# 1D     0.097498  alpha080
# alpha080 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha080 -0.051065       -0.000057   0.904702
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha081 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.051631  0.149889         -0.344459   -6.562818  1.830828e-10  0.242872
#
#     IC Kurtosis AlphaName
# 1D    -0.537963  alpha081
# alpha081 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha081 -1.114446       -0.001492   0.516808
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha082 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.029671  0.179528         -0.165275   -3.127144      0.00191  0.216774
#
#     IC Kurtosis AlphaName
# 1D     0.241158  alpha082
# alpha082 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha082 -0.727084       -0.001136    0.56827
# Dropped 1.9% entries from factor data: 0.4% in forward returns computation and 1.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha083 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.046205  0.088883          0.519838         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha083
# alpha083 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha083  2.272582        0.002102   1.982443
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha084 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.043634  0.149941         -0.291011   -5.389605  1.318091e-07  0.213919
#
#     IC Kurtosis AlphaName
# 1D    -0.616718  alpha084
# alpha084 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha084 -0.639517       -0.000839   0.673795
# Dropped 18.0% entries from factor data: 0.4% in forward returns computation and 17.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha085 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.013325  0.108038          0.123332         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha085
# alpha085 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha085  0.957922        0.000881   1.214194
# alpha086 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha087 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.005686  0.072515          0.078414    1.460692     0.145007 -0.115185
#
#     IC Kurtosis AlphaName
# 1D    -0.213068  alpha087
# alpha087 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha087 -0.212334       -0.000179    0.89869
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha088 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.027519  0.202964         -0.135584   -2.511046     0.012498  0.093218
#
#     IC Kurtosis AlphaName
# 1D     0.256359  alpha088
# alpha088 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha088 -0.476828       -0.000794   0.640306
# Dropped 0.6% entries from factor data: 0.4% in forward returns computation and 0.2% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha089 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.008358  0.108489         -0.077038   -1.465745     0.143588  0.186883
#
#     IC Kurtosis AlphaName
# 1D     0.128747  alpha089
# alpha089 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha089  0.085414        0.000086   0.965389
# Dropped 27.6% entries from factor data: 22.4% in forward returns computation and 5.3% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha090 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.021249  0.072373          0.293601         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha090
# alpha090 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha090  2.141123        0.001671   1.667417
# Dropped 4.0% entries from factor data: 0.4% in forward returns computation and 3.7% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha091 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.025049  0.099563          0.251593         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha091
# alpha091 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha091  1.312975         0.00119   1.426359
# Dropped 100.0% entries from factor data: 0.4% in forward returns computation and 99.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha092 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha093 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.013111  0.121721          0.107713    1.994875      0.04685  0.005832
#
#     IC Kurtosis AlphaName
# 1D     -0.35562  alpha093
# alpha093 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha093 -0.153905       -0.000156    0.88828
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha094 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.023751  0.135665         -0.175068   -3.194687     0.001534  0.256562
#
#     IC Kurtosis AlphaName
# 1D     0.174673  alpha094
# alpha094 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha094 -0.522686       -0.000566   0.771343
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha095 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.054579  0.143018         -0.381626   -7.078116  8.294694e-12  0.062192
#
#     IC Kurtosis AlphaName
# 1D     0.034917  alpha095
# alpha095 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha095 -1.53709        -0.00173   0.508891
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha096 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.005637  0.164982          0.034169    0.643785     0.520132  0.028915
#
#     IC Kurtosis AlphaName
# 1D     0.437588  alpha096
# alpha096 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha096  0.399369        0.000565   1.073511
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha097 done
#      IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.05293  0.14428         -0.366853   -6.902303  2.383695e-11  0.235021
#
#     IC Kurtosis AlphaName
# 1D    -0.438446  alpha097
# alpha097 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha097 -1.059999       -0.001366   0.554103
# alpha098 error continue
# Dropped 5.2% entries from factor data: 0.4% in forward returns computation and 4.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha099 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.038473  0.076583          0.502372         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha099
# alpha099 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha099  1.663185        0.001568   1.607927
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha100 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.046577  0.146971          -0.31691   -5.877802  9.854696e-09  0.225224
#
#     IC Kurtosis AlphaName
# 1D    -0.521562  alpha100
# alpha100 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha100 -0.564789       -0.000711   0.709314
# alpha101 error continue
# Dropped 0.8% entries from factor data: 0.4% in forward returns computation and 0.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha102 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.01308  0.110819         -0.118031   -2.239488     0.025736 -0.132139
#
#     IC Kurtosis AlphaName
# 1D     0.096777  alpha102
# alpha102 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha102 -0.738091       -0.000789   0.698298
# Dropped 100.0% entries from factor data: 0.4% in forward returns computation and 99.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha103 error continue
# ...
# alpha158 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)  IC Skew  \
# 1D -0.087796  0.224491         -0.391088   -7.451223  6.862212e-13  0.51298
#
#     IC Kurtosis AlphaName
# 1D    -0.087832  alpha158
# alpha158 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha158 -1.356573       -0.002578   0.309219
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha159 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.097405  0.271115         -0.359275   -6.614946  1.455405e-10  0.359089
#
#     IC Kurtosis AlphaName
# 1D    -0.487614  alpha159
# alpha159 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha159 -1.004517       -0.002122   0.370411
# Dropped 26.0% entries from factor data: 22.6% in forward returns computation and 3.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha160 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.027088  0.111492          0.242957    4.493066      0.00001  0.037795
#
#     IC Kurtosis AlphaName
# 1D    -0.156864  alpha160
# alpha160 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha160  0.951528        0.001186   1.360056
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha161 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.009623  0.125351          0.076771    1.438308      0.15124  0.032559
#
#     IC Kurtosis AlphaName
# 1D    -0.422767  alpha161
# alpha161 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha161 -0.316903       -0.000317   0.838587
# Dropped 26.4% entries from factor data: 0.4% in forward returns computation and 26.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha162 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D -0.040695  0.123326         -0.329981         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha162
# alpha162 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha162 -0.670809       -0.000809   0.756376
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha163 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.030664  0.113466           0.27025    5.012389  8.632035e-07  0.189279
#
#     IC Kurtosis AlphaName
# 1D      0.68314  alpha163
# alpha163 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha163  1.497841        0.001487    1.56741
# Dropped 1.0% entries from factor data: 0.4% in forward returns computation and 0.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha164 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.00586  0.118341         -0.049516   -0.925033      0.35559  0.025711
#
#     IC Kurtosis AlphaName
# 1D    -0.395746  alpha164
# alpha164 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha164  0.583441        0.000618   1.156172
# Dropped 0.5% entries from factor data: 0.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha165 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.012143  0.121928         -0.099589   -1.633384     0.103563 -0.079567
#
#     IC Kurtosis AlphaName
# 1D    -0.382847  alpha165
# alpha165 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha165  0.159847        0.000161   0.994445
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha166 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.044514  0.174759          0.254715    4.584869     0.000007  0.110538
#
#     IC Kurtosis AlphaName
# 1D     0.328011  alpha166
# alpha166 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha166  0.583817        0.000849     1.1609
# Dropped 22.0% entries from factor data: 22.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha167 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.010719  0.125479          0.085428    1.602773     0.109884  0.016236
#
#     IC Kurtosis AlphaName
# 1D    -0.375813  alpha167
# alpha167 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha167 -0.570432        -0.00061   0.749018
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha168 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.020042  0.108732          0.184328    3.418775     0.000705  0.216591
#
#     IC Kurtosis AlphaName
# 1D    -0.043084  alpha168
# alpha168 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha168  0.276163        0.000294   1.030361
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha169 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.000847  0.096081          0.008812     0.16153     0.871774  0.030529
#
#     IC Kurtosis AlphaName
# 1D       -0.255  alpha169
# alpha169 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha169  0.98391        0.000815   1.261042
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha170 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.01845  0.109389         -0.168661   -3.128188      0.00191 -0.204494
#
#     IC Kurtosis AlphaName
# 1D    -0.023036  alpha170
# alpha170 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha170 -1.723837       -0.001816   0.499265
# Dropped 0.5% entries from factor data: 0.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha171 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.003433  0.139396          0.024626    0.469192     0.639215  0.214274
#
#     IC Kurtosis AlphaName
# 1D     0.661267  alpha171
# alpha171 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha171 -0.69228        -0.00086   0.660977
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha172 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.001312  0.123299         -0.010637   -0.197284     0.843722 -0.131766
#
#     IC Kurtosis AlphaName
# 1D      0.18391  alpha172
# alpha172 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha172  0.21638        0.000213   1.012501
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha173 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.022924  0.141722          0.161754     3.08183     0.002215 -0.012671
#
#     IC Kurtosis AlphaName
# 1D    -0.558658  alpha173
# alpha173 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha173  0.359171        0.000397   1.064538
# Dropped 26.2% entries from factor data: 22.6% in forward returns computation and 3.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha174 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.027372  0.116554          0.234844     4.33667     0.000019  0.050779
#
#     IC Kurtosis AlphaName
# 1D    -0.194201  alpha174
# alpha174 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha174  1.186592        0.001478   1.501647
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha175 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.007886  0.124291           0.06345    1.198859      0.23138  -0.0064
#
#     IC Kurtosis AlphaName
# 1D    -0.373585  alpha175
# alpha175 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha175 -0.669631       -0.000678   0.733614
# Dropped 24.3% entries from factor data: 22.4% in forward returns computation and 1.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha176 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.026456  0.072479         -0.365018   -6.799532  4.617482e-11 -0.025886
#
#     IC Kurtosis AlphaName
# 1D    -0.382897  alpha176
# alpha176 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha176 -1.416402       -0.000994   0.686423
# Dropped 100.0% entries from factor data: 0.4% in forward returns computation and 99.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha177 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha178 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.03152  0.157814          -0.19973   -3.800122      0.00017 -0.097441
#
#     IC Kurtosis AlphaName
# 1D    -0.065958  alpha178
# alpha178 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha178 -0.142366       -0.000213   0.801382
# Dropped 22.0% entries from factor data: 22.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha179 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.023849  0.089919         -0.265226   -4.976089     0.000001 -0.119288
#
#     IC Kurtosis AlphaName
# 1D     0.192658  alpha179
# alpha179 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha179 -0.202353       -0.000174   0.896892
# alpha180 error continue
# alpha181 error continue
# Dropped 100.0% entries from factor data: 59.3% in forward returns computation and 40.7% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha182 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha183 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.009115  0.121585         -0.074972   -1.334836     0.182891 -0.046893
#
#     IC Kurtosis AlphaName
# 1D     -0.40716  alpha183
# alpha183 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha183 -0.079466       -0.000078   0.923375
# Dropped 0.7% entries from factor data: 0.7% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha184 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.012987  0.11224         -0.115708    -1.48178      0.14033 -0.156591
#
#     IC Kurtosis AlphaName
# 1D    -0.279177  alpha184
# alpha184 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha184 -1.564799       -0.001757   0.721723
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha185 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.045494  0.164449          0.276646     5.27082  2.339168e-07 -0.639256
#
#     IC Kurtosis AlphaName
# 1D      0.88554  alpha185
# alpha185 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha185  1.608962        0.002302   2.010749
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha186 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.001327  0.117281         -0.011313   -0.207981     0.835369  0.117597
#
#     IC Kurtosis AlphaName
# 1D     0.465399  alpha186
# alpha186 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha186  0.795598         0.00077   1.225105
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha187 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.007097  0.127484          0.055673    1.031078     0.303233  0.050433
#
#     IC Kurtosis AlphaName
# 1D    -0.385079  alpha187
# alpha187 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha187 -0.457817       -0.000463   0.799477
# Dropped 0.6% entries from factor data: 0.4% in forward returns computation and 0.2% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha188 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.002246  0.118699          -0.01892   -0.359968     0.719081 -0.202975
#
#     IC Kurtosis AlphaName
# 1D      0.75108  alpha188
# alpha188 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha188  0.304486        0.000395    1.03174
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha189 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.008807  0.123977          0.071034    1.334598      0.18287  0.035743
#
#     IC Kurtosis AlphaName
# 1D    -0.432543  alpha189
# alpha189 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha189 -0.047351       -0.000047    0.92319
# alpha190 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha191 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.001999  0.101893         -0.019617   -0.371694      0.71034 -0.016117
#
#     IC Kurtosis AlphaName
# 1D     0.031436  alpha191
# alpha191 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha191  0.790742        0.000719   1.226633

# %%
SP = pd.read_csv('ALPHA191_SP_tables.csv')
IC = pd.read_csv('ALPHA191_IC_tables.csv')
all = pd.merge(SP,IC,on=['AlphaName'])


# # 筛选表现好的因子
# good_factors = all[abs(all['SP']) > 2.5]

good_factors = all.sort_values(by=["SP"], ascending=False)  
good_factors = good_factors[['AlphaName','SP','Mean','IC Mean','IC Std.','t-stat(IC)']]
# print("表现好的因子：")
# print(good_factors[["AlphaName", "IC Mean", "Risk-Adjusted IC", "t-stat(IC)", "p-value(IC)"]])
good_factors
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 10
#       6 # # 筛选表现好的因子
#       7 # good_factors = all[abs(all['SP']) > 2.5]
#       9 good_factors = all.sort_values(by=["SP"], ascending=False)
# ---> 10 good_factors = good_factors[['AlphaName','SP','Mean','IC Mean','IC Std.','t-stat(IC)']]
#      11 # print("表现好的因子：")
#      12 # print(good_factors[["AlphaName", "IC Mean", "Risk-Adjusted IC", "t-stat(IC)", "p-value(IC)"]])
#      13 good_factors
#
# File ~/miniconda3/envs/freqtrade-grid/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniconda3/envs/freqtrade-grid/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/freqtrade-grid/lib/python3.11/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Mean'] not in index"
