# %% [markdown]
# ### 1. Load History OHCLV
#
# create a new terminal and
#
# Download-data:
# `
# freqtrade download-data --config user_data/config.json --timeframe 15m --timerange 20240101-20250101
# `
#
# File-like:
# `
# BTC_USDT-15m.feather
# `

# %%
import pandas as pd 
import os
import re
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.append('./')

file_path = '/usr/local/services/freqtrade-grid/user_data/data/binance/futures'
time_frame = '1d'

def extract_coin_symbols(directory):
    coin_list = []
    pattern = re.compile(r'(.+?)_USDT-1d-futures\.feather$')

    for filename in os.listdir(directory):
        match = pattern.match(filename)
        if match:
            coin_symbol = (match.group(1)+':USDT').replace('_','/')
            coin_list.append(coin_symbol)
    
    return coin_list


if os.path.exists(file_path) and os.path.isdir(file_path):
    coins = extract_coin_symbols(file_path)
print(len(coins))
# Out:
# 393

# %% [markdown]
# ### 2. Pair Filter

# %%
top50 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT"
]

top100 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT","ATOM/USDT:USDT","ALGO/USDT:USDT","JUP/USDT:USDT","TIA/USDT:USDT","VIRTUAL/USDT:USDT","INJ/USDT:USDT","QNT/USDT:USDT","STX/USDT:USDT","S/USDT:USDT","DEXE/USDT:USDT","OP/USDT:USDT","FARTCOIN/USDT:USDT","IP/USDT:USDT","FORM/USDT:USDT","SEI/USDT:USDT","A/USDT:USDT","SPX/USDT:USDT","IMX/USDT:USDT","WIF/USDT:USDT","GRT/USDT:USDT","CRV/USDT:USDT","LDO/USDT:USDT","ZEC/USDT:USDT","ENS/USDT:USDT","JASMY/USDT:USDT","THETA/USDT:USDT","CAKE/USDT:USDT","GALA/USDT:USDT","WAL/USDT:USDT","SAND/USDT:USDT","IOTA/USDT:USDT","PYTH/USDT:USDT","PENGU/USDT:USDT","BSV/USDT:USDT","PENDLE/USDT:USDT","KAIA/USDT:USDT"
]

top150 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT","ATOM/USDT:USDT","ALGO/USDT:USDT","JUP/USDT:USDT","TIA/USDT:USDT","VIRTUAL/USDT:USDT","INJ/USDT:USDT","QNT/USDT:USDT","STX/USDT:USDT","S/USDT:USDT","DEXE/USDT:USDT","OP/USDT:USDT","FARTCOIN/USDT:USDT","IP/USDT:USDT","FORM/USDT:USDT","SEI/USDT:USDT","A/USDT:USDT","SPX/USDT:USDT","IMX/USDT:USDT","WIF/USDT:USDT","GRT/USDT:USDT","CRV/USDT:USDT","LDO/USDT:USDT","ZEC/USDT:USDT","ENS/USDT:USDT","JASMY/USDT:USDT","THETA/USDT:USDT","CAKE/USDT:USDT","GALA/USDT:USDT","WAL/USDT:USDT","SAND/USDT:USDT","IOTA/USDT:USDT","PYTH/USDT:USDT","PENGU/USDT:USDT","BSV/USDT:USDT","PENDLE/USDT:USDT","KAIA/USDT:USDT","XTZ/USDT:USDT","RUNE/USDT:USDT","FLOW/USDT:USDT","BRETT/USDT:USDT","ZKJ/USDT:USDT","JTO/USDT:USDT","XCN/USDT:USDT","MANA/USDT:USDT","APE/USDT:USDT","KAITO/USDT:USDT","DEEP/USDT:USDT","ATH/USDT:USDT","GRASS/USDT:USDT","EIGEN/USDT:USDT","EGLD/USDT:USDT","DYDX/USDT:USDT","AR/USDT:USDT","AERO/USDT:USDT","STRK/USDT:USDT","KAVA/USDT:USDT","NEO/USDT:USDT","AXS/USDT:USDT","RSR/USDT:USDT","SUPER/USDT:USDT","LPT/USDT:USDT","ETHFI/USDT:USDT","W/USDT:USDT","CFX/USDT:USDT","SYRUP/USDT:USDT","CHZ/USDT:USDT","MOVE/USDT:USDT","POPCAT/USDT:USDT","MORPHO/USDT:USDT","COMP/USDT:USDT","SAFE/USDT:USDT","SUN/USDT:USDT"
]

top200 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT","ATOM/USDT:USDT","ALGO/USDT:USDT","JUP/USDT:USDT","TIA/USDT:USDT","VIRTUAL/USDT:USDT","INJ/USDT:USDT","QNT/USDT:USDT","STX/USDT:USDT","S/USDT:USDT","DEXE/USDT:USDT","OP/USDT:USDT","FARTCOIN/USDT:USDT","IP/USDT:USDT","FORM/USDT:USDT","SEI/USDT:USDT","A/USDT:USDT","SPX/USDT:USDT","IMX/USDT:USDT","WIF/USDT:USDT","GRT/USDT:USDT","CRV/USDT:USDT","LDO/USDT:USDT","ZEC/USDT:USDT","ENS/USDT:USDT","JASMY/USDT:USDT","THETA/USDT:USDT","CAKE/USDT:USDT","GALA/USDT:USDT","WAL/USDT:USDT","SAND/USDT:USDT","IOTA/USDT:USDT","PYTH/USDT:USDT","PENGU/USDT:USDT","BSV/USDT:USDT","PENDLE/USDT:USDT","KAIA/USDT:USDT","XTZ/USDT:USDT","RUNE/USDT:USDT","FLOW/USDT:USDT","BRETT/USDT:USDT","ZKJ/USDT:USDT","JTO/USDT:USDT","XCN/USDT:USDT","MANA/USDT:USDT","APE/USDT:USDT","KAITO/USDT:USDT","DEEP/USDT:USDT","ATH/USDT:USDT","GRASS/USDT:USDT","EIGEN/USDT:USDT","EGLD/USDT:USDT","DYDX/USDT:USDT","AR/USDT:USDT","AERO/USDT:USDT","STRK/USDT:USDT","KAVA/USDT:USDT","NEO/USDT:USDT","AXS/USDT:USDT","RSR/USDT:USDT","SUPER/USDT:USDT","LPT/USDT:USDT","ETHFI/USDT:USDT","W/USDT:USDT","CFX/USDT:USDT","SYRUP/USDT:USDT","CHZ/USDT:USDT","MOVE/USDT:USDT","POPCAT/USDT:USDT","MORPHO/USDT:USDT","COMP/USDT:USDT","SAFE/USDT:USDT","SUN/USDT:USDT","TWT/USDT:USDT","JST/USDT:USDT","AKT/USDT:USDT","OM/USDT:USDT","AXL/USDT:USDT","TURBO/USDT:USDT","BERA/USDT:USDT","1INCH/USDT:USDT","MEW/USDT:USDT","MINA/USDT:USDT","KSM/USDT:USDT","AI16Z/USDT:USDT","DASH/USDT:USDT","PNUT/USDT:USDT","ZRO/USDT:USDT","NXPC/USDT:USDT","SFP/USDT:USDT","NOT/USDT:USDT","SNX/USDT:USDT","GLM/USDT:USDT","ROSE/USDT:USDT","ZIL/USDT:USDT","MOCA/USDT:USDT","MASK/USDT:USDT","BLUR/USDT:USDT","QTUM/USDT:USDT","CKB/USDT:USDT","MOODENG/USDT:USDT","ASTR/USDT:USDT","ZK/USDT:USDT","ZRX/USDT:USDT","GAS/USDT:USDT","ORDI/USDT:USDT","BAT/USDT:USDT","VANA/USDT:USDT","ACH/USDT:USDT"
]

target_coins = coins
# print(target_coins)

# %% [markdown]
# ### 3. Load History OHLCV

# %%
def extract_coin_data(directory):
    coin_list = {}
    symbols = []
    pattern = re.compile(r'(.+?)_USDT-1d-futures\.feather$')

    for filename in os.listdir(directory):
        match = pattern.match(filename)
        if match:
            coin_symbol = (match.group(1)+':USDT').replace('_','/')
            if coin_symbol in target_coins: 
                df = pd.read_feather(f'{directory}/{filename}')
                df = df.reset_index(drop=True)
                if len(df) > 0 :
                    coin_list[coin_symbol] = df
                    symbols.append(coin_symbol)
    
    return coin_list,symbols

if os.path.exists(file_path) and os.path.isdir(file_path):
    coins,symbols = extract_coin_data(file_path)
print(len(coins))
# Out:
# 393

# %% [markdown]
# ### 3. History Data Transform

# %%
import pandas as pd
close_dfs = []
open_dfs = []
high_dfs = []
low_dfs = []
volume_dfs = []


for symbol, df in coins.items():
    
    temp_df = df[['date', 'close']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    close_dfs.append(temp_df)



    temp_df = df[['date', 'open']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    open_dfs.append(temp_df)


    temp_df = df[['date', 'high']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    high_dfs.append(temp_df)
    

    temp_df = df[['date', 'low']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    low_dfs.append(temp_df)

    temp_df = df[['date', 'volume']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    volume_dfs.append(temp_df)



close = pd.concat(close_dfs, axis=1)
open = pd.concat(open_dfs, axis=1)
high = pd.concat(high_dfs, axis=1)
low = pd.concat(low_dfs, axis=1)
volume = pd.concat(volume_dfs, axis=1)
amount = close.mul(volume, fill_value=1)

# %% [markdown]
# ### 4. OHLCV Filter

# %%
start_time = '2024-06-01'
end_time = '2025-06-01'
close_filter = close[(close.index > start_time) & (close.index < end_time)]
open_filter = open[(open.index > start_time) & (open.index < end_time)]
high_filter = high[(high.index > start_time) & (high.index < end_time)]
low_filter = low[(low.index > start_time) & (low.index < end_time)]
volume_filter = volume[(volume.index > start_time) & (volume.index < end_time)]
amount_filter = amount[(amount.index > start_time) & (amount.index < end_time)]

import matplotlib.pyplot as plt
_, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))
high_norm = high_filter/high_filter.bfill().iloc[0] 
close_norm = close_filter/close_filter.bfill().iloc[0] 
high_norm.mean(axis=1).plot(ax=ax1, figsize=(15,6),grid=True)
close_norm.mean(axis=1).plot(ax=ax2, figsize=(15,6),grid=True);

# %% [markdown]
# ### 5. Define Factor

# %%
# Factor in WorldQuant 101
import Alpha101 as alpha101

df_data = {
    'open' : open_filter,
    'close' : close_filter,
    'high' : high_filter,
    'low' : low_filter,
    'volume' : volume_filter, 
}

alpha_all_in_one = alpha101.Alphas101(df_data)
alpha_list = [f"alpha{num:03d}" for num in range(1, 102)]

# %% [markdown]
# ### 6. Data transfrom and process

# %%
import alphalens.utils as utils
import alphalens.tears as tears
import alphalens.performance as perf
import alphalens.plotting as plot
import numpy as np

IC_tables = []
SP_tables = []


for alpha_name in alpha_list:
    try:
        method = getattr(alpha_all_in_one, alpha_name)
        single_alpha = method() 
        factor = single_alpha.stack()
        factor.index.names = ['date', 'asset']
        factor = factor.dropna()  # 清理缺失值
        price = close_filter
    
        factor_data = utils.get_clean_factor_and_forward_returns(
            factor=factor,
            prices=price,
            periods=(1,),  
            quantiles = 10
        )
        
        IC = perf.factor_information_coefficient(factor_data)
        IC_table = plot.plot_information_table(IC,return_df=True)
        IC_table['AlphaName'] = alpha_name
        IC_tables.append(IC_table)
        print(f'{alpha_name} done \n {IC_table}')



        mean_return_by_q, _ = perf.mean_return_by_quantile(
            factor_data,
            by_date=True, 
            demeaned=False,
            group_adjust=False
        )
        top_quantile_daily = mean_return_by_q.loc[3]  # 最高分组每日收益
        bottom_quantile_daily = mean_return_by_q.loc[1]  # 最低分组每日收益
        long_short_daily = top_quantile_daily - bottom_quantile_daily # 计算 Long-Short 组合（最高减最低）
        long_short_cumulative = perf.cumulative_returns(long_short_daily)
        mean_return = long_short_daily.mean()
        std_dev = long_short_daily.std()
        sharpe_ratio = (mean_return) / std_dev * np.sqrt(365)
        SP_table = pd.DataFrame([{
                    "AlphaName":alpha_name,
                    "SP":float(sharpe_ratio),
                    "Pro Daily Mean":float(mean_return),
                    "Pro Total":float(long_short_cumulative.iloc[-1])
                }])
        print(f'{alpha_name} done \n {SP_table}')
        SP_tables.append(SP_table)     
    except:
        print(f'{alpha_name} error continue')
    

if len(IC_tables) > 0 :
    IC_df = pd.concat(IC_tables)
    IC_df.to_csv('ALPHA101_IC_tables.csv')

if len(SP_tables) > 0 :
    SP_df = pd.concat(SP_tables)
    SP_df.to_csv('ALPHA101_SP_tables.csv')
# Out:
# Dropped 100.0% entries from factor data: 0.4% in forward returns computation and 99.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha001 error continue
# Dropped 23.7% entries from factor data: 22.6% in forward returns computation and 1.1% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha002 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.020824  0.075278          0.276631     5.21946  3.060244e-07  0.124356
#
#     IC Kurtosis AlphaName
# 1D    -0.110036  alpha002
# alpha002 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha002  1.641834        0.001175   1.469528
# Dropped 25.0% entries from factor data: 22.6% in forward returns computation and 2.5% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha003 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.018124  0.068336           0.26522         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha003
# alpha003 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha003 -0.242109       -0.000165   0.916591
# Dropped 100.0% entries from factor data: 0.4% in forward returns computation and 99.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha004 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha005 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.008837  0.114404          0.077243    1.453314     0.147025  0.057901
#
#     IC Kurtosis AlphaName
# 1D     0.021443  alpha005
# alpha005 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha005  0.447009        0.000356   1.089036
# Dropped 24.0% entries from factor data: 22.6% in forward returns computation and 1.5% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha006 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.018665  0.102809          0.181555     3.41594      0.00071 -0.120266
#
#     IC Kurtosis AlphaName
# 1D      0.99056  alpha006
# alpha006 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha006  1.601968        0.001098   1.430698
# Dropped 97.6% entries from factor data: 0.4% in forward returns computation and 97.2% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha007 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha008 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.014204  0.10576          0.134303    2.505383     0.012689  0.145198
#
#     IC Kurtosis AlphaName
# 1D     0.338084  alpha008
# alpha008 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha008  0.774594        0.000763   1.226174
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha009 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.015779  0.10847          0.145473    2.767811     0.005934  0.102007
#
#     IC Kurtosis AlphaName
# 1D     0.157673  alpha009
# alpha009 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha009 -1.211099       -0.001165   0.616155
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha010 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.017433  0.101994          0.170924     3.25205     0.001254  0.130113
#
#     IC Kurtosis AlphaName
# 1D    -0.294223  alpha010
# alpha010 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha010 -1.122591       -0.001081   0.635373
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha011 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.003117  0.108508          0.028724    0.545003      0.58609  0.204256
#
#     IC Kurtosis AlphaName
# 1D     0.790939  alpha011
# alpha011 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha011 -0.132985        -0.00011   0.918995
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha012 done
#      IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.01736  0.08914           0.19475    3.705378     0.000244 -0.010798
#
#     IC Kurtosis AlphaName
# 1D     0.694823  alpha012
# alpha012 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha012 -0.372784       -0.000322    0.84724
# Dropped 5.2% entries from factor data: 0.4% in forward returns computation and 4.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha013 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.038473  0.076583          0.502372         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha013
# alpha013 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha013  1.481941        0.001426   1.529357
# Dropped 1.4% entries from factor data: 0.4% in forward returns computation and 1.1% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha014 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.020273  0.105821          0.191582    3.604601     0.000358 -0.032297
#
#     IC Kurtosis AlphaName
# 1D     1.473949  alpha014
# alpha014 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha014  2.67079        0.002284   2.138853
# Dropped 25.1% entries from factor data: 22.5% in forward returns computation and 2.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha015 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.034623  0.077814          0.444943         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha015
# alpha015 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha015  1.044644        0.000716   1.242777
# Dropped 1.9% entries from factor data: 0.4% in forward returns computation and 1.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha016 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.046205  0.088883          0.519838         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha016
# alpha016 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha016  2.471248        0.002198   2.059074
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha017 done
#      IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.02697   0.1133          0.238043    4.389304     0.000015  0.389322
#
#     IC Kurtosis AlphaName
# 1D       0.9997  alpha017
# alpha017 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha017  3.752989        0.003392    3.00905
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha018 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D -0.001161  0.111091         -0.010448   -0.197969     0.843181   0.0375
#
#     IC Kurtosis AlphaName
# 1D    -0.066512  alpha018
# alpha018 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha018 -1.958298       -0.001706   0.515297
# Dropped 1.0% entries from factor data: 1.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha019 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.018896  0.173187          0.109106     1.15981     0.248593 -0.012549
#
#     IC Kurtosis AlphaName
# 1D    -0.124136  alpha019
# alpha019 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha019  2.591475        0.002609   1.315521
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha020 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.00582  0.087405          0.066592    1.266991     0.205975 -0.464177
#
#     IC Kurtosis AlphaName
# 1D     0.174811  alpha020
# alpha020 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha020 -0.576106        -0.00036   0.855578
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha021 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha022 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.005442  0.085354          0.063756    1.182507     0.237824 -0.022173
#
#     IC Kurtosis AlphaName
# 1D     0.065617  alpha022
# alpha022 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha022 -0.500557       -0.000353   0.858568
# Dropped 86.1% entries from factor data: 22.6% in forward returns computation and 63.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha023 error continue
# Dropped 4.0% entries from factor data: 0.4% in forward returns computation and 3.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha024 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.011583  0.112574          0.102894         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha024
# alpha024 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha024 -1.70031       -0.001482   0.567668
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha025 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.030718  0.113479          0.270689    5.020531  8.298062e-07  0.189475
#
#     IC Kurtosis AlphaName
# 1D     0.681902  alpha025
# alpha025 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha025  0.928254         0.00086   1.274416
# Dropped 31.7% entries from factor data: 22.5% in forward returns computation and 9.3% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha026 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.021939  0.093125          0.235587         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha026
# alpha026 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha026  1.500151        0.001088    1.36693
# Dropped 100.0% entries from factor data: 22.5% in forward returns computation and 77.5% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha027 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha028 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.002025  0.098645         -0.020523   -0.391021     0.696012 -0.035764
#
#     IC Kurtosis AlphaName
# 1D    -0.234259  alpha028
# alpha028 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha028  2.107505        0.001839   1.853962
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha029 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.012208  0.104653          0.116657    2.188675     0.029279  0.021968
#
#     IC Kurtosis AlphaName
# 1D     0.411507  alpha029
# alpha029 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha029  1.566465        0.001325   1.522382
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha030 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.009896  0.109359          0.090488    1.678302     0.094199  0.098409
#
#     IC Kurtosis AlphaName
# 1D    -0.100221  alpha030
# alpha030 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha030  0.022495        0.000018   0.966208
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha031 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.011983  0.096881          0.123692    2.294139     0.022386 -0.016193
#
#     IC Kurtosis AlphaName
# 1D     0.834415  alpha031
# alpha031 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha031  0.423829        0.000295   1.073586
# Dropped 0.3% entries from factor data: 0.3% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha032 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.086298  0.164235          0.525457     9.92821  1.145080e-20 -0.227732
#
#     IC Kurtosis AlphaName
# 1D    -0.191568  alpha032
# alpha032 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha032  3.262577        0.002604   2.428664
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha033 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.035163  0.179025          0.196416    3.742231     0.000212  0.288246
#
#     IC Kurtosis AlphaName
# 1D     0.279265  alpha033
# alpha033 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha033  0.901099        0.000993   1.321366
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha034 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.018584  0.118772          0.156472    2.977083     0.003106  0.069572
#
#     IC Kurtosis AlphaName
# 1D     0.093342  alpha034
# alpha034 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha034  1.469964        0.001281   1.512166
# Dropped 42.0% entries from factor data: 0.4% in forward returns computation and 41.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha035 error continue
# Dropped 0.7% entries from factor data: 0.7% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha036 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.013435  0.111434          0.120562    1.543953     0.124539  0.247742
#
#     IC Kurtosis AlphaName
# 1D    -0.117259  alpha036
# alpha036 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha036  1.363756        0.001034   1.164619
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha037 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.014646  0.11295          0.129666    2.470466     0.013954  0.072259
#
#     IC Kurtosis AlphaName
# 1D      0.17849  alpha037
# alpha037 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha037 -0.571767       -0.000489   0.797653
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha038 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.031689  0.148411          0.213521    4.017374     0.000072  0.360618
#
#     IC Kurtosis AlphaName
# 1D     0.881068  alpha038
# alpha038 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha038  0.927248        0.000881   1.288688
# Dropped 1.0% entries from factor data: 1.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha039 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.007899  0.132903          0.059438    0.631832     0.528784  0.092022
#
#     IC Kurtosis AlphaName
# 1D     0.846951  alpha039
# alpha039 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha039 -0.287489       -0.000259   0.955273
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha040 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.029324  0.104534          0.280525    5.278055  2.285123e-07 -0.128821
#
#     IC Kurtosis AlphaName
# 1D    -0.100593  alpha040
# alpha040 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha040  1.589855        0.001304   1.519213
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha041 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.009781  0.108527          0.090122    1.717062     0.086823  0.245408
#
#     IC Kurtosis AlphaName
# 1D     0.680289  alpha041
# alpha041 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha041 -0.216621       -0.000198   0.881474
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha042 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.008341  0.153764         -0.054243   -1.033471     0.302073  0.401196
#
#     IC Kurtosis AlphaName
# 1D     0.061498  alpha042
# alpha042 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha042 -1.283402        -0.00102   0.662182
# Dropped 18.3% entries from factor data: 0.4% in forward returns computation and 17.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha043 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.013908  0.10753          0.129343         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha043
# alpha043 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha043  0.966406        0.000731   1.180196
# Dropped 23.2% entries from factor data: 22.6% in forward returns computation and 0.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha044 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.047088  0.090581          0.519844    9.849631  2.062360e-20 -0.146881
#
#     IC Kurtosis AlphaName
# 1D    -0.280955  alpha044
# alpha044 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha044  1.707827        0.001256   1.514702
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha045 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.009554  0.086172          0.110877    2.041459     0.041981 -0.255855
#
#     IC Kurtosis AlphaName
# 1D       0.7819  alpha045
# alpha045 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha045  0.463252         0.00034   1.085459
# Dropped 79.2% entries from factor data: 0.4% in forward returns computation and 78.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha046 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha047 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.030159  0.124268         -0.242694   -4.501301     0.000009  0.092353
#
#     IC Kurtosis AlphaName
# 1D     -0.52057  alpha047
# alpha047 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha047 -1.303867       -0.000887   0.716054
# alpha048 error continue
# Dropped 11.1% entries from factor data: 0.4% in forward returns computation and 10.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha049 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.024382  0.108236          0.225265         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha049
# alpha049 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha049 -0.032035       -0.000031   0.935776
# Dropped 29.2% entries from factor data: 22.4% in forward returns computation and 6.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha050 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.035483  0.075389          0.470664         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha050
# alpha050 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha050 -0.65561       -0.000456   0.840167
# Dropped 19.9% entries from factor data: 0.4% in forward returns computation and 19.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha051 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.024473  0.112341          0.217848         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha051
# alpha051 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha051 -0.108655       -0.000106   0.922779
# Dropped 0.9% entries from factor data: 0.9% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha052 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.005784  0.152471          0.037938    0.420755     0.674674  0.030617
#
#     IC Kurtosis AlphaName
# 1D    -0.357687  alpha052
# alpha052 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha052 -0.614901       -0.000593   0.910523
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha053 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.026147  0.120543          0.216908      4.0811     0.000055  0.370626
#
#     IC Kurtosis AlphaName
# 1D      0.58626  alpha053
# alpha053 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha053  1.470514        0.001365   1.533434
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha054 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.013901  0.13616         -0.102096   -1.945192     0.052526  0.083491
#
#     IC Kurtosis AlphaName
# 1D     0.165997  alpha054
# alpha054 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha054 -0.736001       -0.000524   0.799521
# Dropped 25.2% entries from factor data: 22.6% in forward returns computation and 2.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha055 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.026403  0.07245          0.364433    6.788639  4.935709e-11  0.025478
#
#     IC Kurtosis AlphaName
# 1D    -0.376488  alpha055
# alpha055 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha055  0.816282        0.000552   1.176636
# alpha056 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha057 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.01444  0.110975          0.130119    2.374458     0.018143  0.377466
#
#     IC Kurtosis AlphaName
# 1D     1.040127  alpha057
# alpha057 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha057 -0.781097       -0.000565   0.802795
# alpha058 error continue
# alpha059 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha060 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.001985  0.127583         -0.015559   -0.292738     0.769895  0.141182
#
#     IC Kurtosis AlphaName
# 1D     0.270973  alpha060
# alpha060 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha060  0.302854        0.000284   1.045092
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha061 error continue
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha062 error continue
# alpha063 error continue
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha064 error continue
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha065 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha066 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.005895  0.072975          0.080783    1.504822     0.133282 -0.074693
#
#     IC Kurtosis AlphaName
# 1D    -0.195348  alpha066
# alpha066 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha066  0.315426        0.000237   1.047747
# alpha067 error continue
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha068 error continue
# alpha069 error continue
# alpha070 error continue
# Dropped 100.0% entries from factor data: 0.4% in forward returns computation and 99.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha071 error continue
# Dropped 24.6% entries from factor data: 22.1% in forward returns computation and 2.5% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha072 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.023672  0.095271          0.248471     4.57483     0.000007 -0.069156
#
#     IC Kurtosis AlphaName
# 1D     0.142108  alpha072
# alpha072 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha072 -0.014009       -0.000011   0.958485
# Dropped 90.8% entries from factor data: 0.4% in forward returns computation and 90.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha073 error continue
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha074 error continue
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha075 error continue
# alpha076 error continue
# Dropped 5.3% entries from factor data: 0.4% in forward returns computation and 5.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha077 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.013267  0.09905         -0.133947   -2.403589     0.016802  0.007707
#
#     IC Kurtosis AlphaName
# 1D     0.093838  alpha077
# alpha077 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha077 -0.166751       -0.000109    0.94146
# Dropped 29.7% entries from factor data: 22.6% in forward returns computation and 7.1% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha078 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.02274  0.088904          0.255776         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha078
# alpha078 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha078  0.247711         0.00019   1.026932
# alpha079 error continue
# alpha080 error continue
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha081 error continue
# alpha082 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha083 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.009866  0.114503           0.08616    1.627948     0.104421  0.352535
#
#     IC Kurtosis AlphaName
# 1D     0.977656  alpha083
# alpha083 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha083 -1.433281       -0.001088   0.653135
# Dropped 19.3% entries from factor data: 0.7% in forward returns computation and 18.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha084 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D -0.01313  0.112651         -0.116558         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha084
# alpha084 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha084  0.809772        0.000642   1.152639
# Dropped 25.2% entries from factor data: 22.6% in forward returns computation and 2.6% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha085 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.012748  0.091363          0.139529    2.599136     0.009746  0.110123
#
#     IC Kurtosis AlphaName
# 1D    -0.092535  alpha085
# alpha085 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha085  0.14058        0.000114   0.998233
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha086 error continue
# alpha087 error continue
# Dropped 8.4% entries from factor data: 0.4% in forward returns computation and 8.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha088 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.072985  0.141559          0.515583         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha088
# alpha088 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha088  1.660327        0.002186   1.817833
# alpha089 error continue
# alpha090 error continue
# alpha091 error continue
# Dropped 100.0% entries from factor data: 20.9% in forward returns computation and 79.1% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha092 error continue
# alpha093 error continue
# Dropped 30.7% entries from factor data: 0.4% in forward returns computation and 30.3% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha094 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D -0.000257  0.119011         -0.002162         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha094
# alpha094 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha094  0.131537        0.000116   0.993807
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha095 error continue
#                            ZEREBRO/USDT:USDT  NFP/USDT:USDT  B3/USDT:USDT  \
# date
# 2024-06-02 00:00:00+00:00           0.000000       0.000000      0.000000
# 2024-06-03 00:00:00+00:00           0.000000       0.000000      0.000000
# 2024-06-04 00:00:00+00:00           0.000000       0.000000      0.000000
# 2024-06-05 00:00:00+00:00           0.000000       0.000000      0.000000
# 2024-06-06 00:00:00+00:00           0.000000       0.331611      0.000000
# ...                                      ...            ...           ...
# 2025-05-27 00:00:00+00:00           0.967086       0.227232      0.000000
# 2025-05-28 00:00:00+00:00           0.000000      -0.041904      0.000000
# 2025-05-29 00:00:00+00:00           0.000000      -0.243709     -0.563827
# 2025-05-30 00:00:00+00:00           0.000000       0.490511     -0.452124
# 2025-05-31 00:00:00+00:00           0.000000       0.260754      0.783914
#
#                            KAS/USDT:USDT  1000X/USDT:USDT  AVAX/USDT:USDT  \
# date
# 2024-06-02 00:00:00+00:00       0.000000         0.000000        0.000000
# 2024-06-03 00:00:00+00:00       0.000000         0.000000        0.000000
# 2024-06-04 00:00:00+00:00       0.000000         0.000000        0.000000
# 2024-06-05 00:00:00+00:00       0.976999         0.000000        0.000000
# 2024-06-06 00:00:00+00:00       0.376311         0.000000        0.000000
# ...                                  ...              ...             ...
# 2025-05-27 00:00:00+00:00      -0.877448         0.801793        0.000000
# 2025-05-28 00:00:00+00:00       0.000000         0.641708        0.842777
# 2025-05-29 00:00:00+00:00      -0.185952         0.834642       -0.129197
# 2025-05-30 00:00:00+00:00       0.157291         0.979059       -0.129197
# 2025-05-31 00:00:00+00:00      -0.182271        -0.359763       -0.663914
#
#                            BB/USDT:USDT  COTI/USDT:USDT  QTUM/USDT:USDT  \
# date
# 2024-06-02 00:00:00+00:00      0.000000        0.000000        0.000000
# 2024-06-03 00:00:00+00:00      0.000000        0.000000        0.000000
# 2024-06-04 00:00:00+00:00      0.000000        0.000000        0.000000
# 2024-06-05 00:00:00+00:00      0.758738        0.313573        0.000000
# 2024-06-06 00:00:00+00:00      0.833238        0.000000        0.000000
# ...                                 ...             ...             ...
# 2025-05-27 00:00:00+00:00      0.903865       -0.279751       -0.116642
# 2025-05-28 00:00:00+00:00      0.901774       -0.521672        0.889297
# 2025-05-29 00:00:00+00:00      0.629941       -0.931334        0.927173
# 2025-05-30 00:00:00+00:00      0.750479       -0.753667        0.000000
# 2025-05-31 00:00:00+00:00      0.701047       -0.279209       -0.683130
#
#                            FIO/USDT:USDT  ...  1000FLOKI/USDT:USDT  \
# date                                      ...
# 2024-06-02 00:00:00+00:00       0.000000  ...             0.000000
# 2024-06-03 00:00:00+00:00       0.000000  ...             0.000000
# 2024-06-04 00:00:00+00:00       0.000000  ...             0.000000
# 2024-06-05 00:00:00+00:00       0.000000  ...             0.938103
# 2024-06-06 00:00:00+00:00       0.000000  ...             0.724000
# ...                                  ...  ...                  ...
# 2025-05-27 00:00:00+00:00      -0.673626  ...             0.391925
# 2025-05-28 00:00:00+00:00      -0.448882  ...             0.152277
# 2025-05-29 00:00:00+00:00      -0.323287  ...             0.750613
# 2025-05-30 00:00:00+00:00      -0.864242  ...             0.675224
# 2025-05-31 00:00:00+00:00      -0.674200  ...             0.890724
#
#                            SFP/USDT:USDT  METIS/USDT:USDT  EDU/USDT:USDT  \
# date
# 2024-06-02 00:00:00+00:00       0.000000              0.0       0.000000
# 2024-06-03 00:00:00+00:00       0.000000              0.0       0.000000
# 2024-06-04 00:00:00+00:00       0.000000              0.0       0.000000
# 2024-06-05 00:00:00+00:00       0.092136              0.0       0.876958
# 2024-06-06 00:00:00+00:00       0.274074              0.0       0.925564
# ...                                  ...              ...            ...
# 2025-05-27 00:00:00+00:00       0.180319              0.0      -0.355744
# 2025-05-28 00:00:00+00:00       0.229416              0.0      -0.013607
# 2025-05-29 00:00:00+00:00       0.870388              0.0      -0.118812
# 2025-05-30 00:00:00+00:00       0.991837              0.0      -0.927273
# 2025-05-31 00:00:00+00:00       0.733709              0.0      -0.792553
#
#                            COOKIE/USDT:USDT  PONKE/USDT:USDT  LSK/USDT:USDT  \
# date
# 2024-06-02 00:00:00+00:00          0.000000         0.000000       0.000000
# 2024-06-03 00:00:00+00:00          0.000000         0.000000       0.000000
# 2024-06-04 00:00:00+00:00          0.000000         0.000000       0.000000
# 2024-06-05 00:00:00+00:00          0.000000         0.000000      -0.349074
# 2024-06-06 00:00:00+00:00          0.000000         0.000000       0.000000
# ...                                     ...              ...            ...
# 2025-05-27 00:00:00+00:00         -0.228056         0.815884       0.000000
# 2025-05-28 00:00:00+00:00          0.692591         0.568184       0.000000
# 2025-05-29 00:00:00+00:00          0.946690         0.706991       0.000000
# 2025-05-30 00:00:00+00:00          0.692825         0.050642       0.000000
# 2025-05-31 00:00:00+00:00         -0.109580         0.049482       0.000000
#
#                            BAND/USDT:USDT  T/USDT:USDT  PROM/USDT:USDT
# date
# 2024-06-02 00:00:00+00:00        0.000000     0.000000        0.000000
# 2024-06-03 00:00:00+00:00        0.000000     0.000000        0.000000
# 2024-06-04 00:00:00+00:00        0.000000     0.000000        0.000000
# 2024-06-05 00:00:00+00:00       -0.416025     0.000000        0.000000
# 2024-06-06 00:00:00+00:00        0.375823    -0.054313        0.000000
# ...                                   ...          ...             ...
# 2025-05-27 00:00:00+00:00       -0.082479     0.647298        0.000000
# 2025-05-28 00:00:00+00:00       -0.045980     0.442326        0.000000
# 2025-05-29 00:00:00+00:00        0.413820     0.365509        0.907265
# 2025-05-30 00:00:00+00:00        1.000000     0.646195        0.700301
# 2025-05-31 00:00:00+00:00        1.000000    -0.373177        0.739345
#
# [364 rows x 393 columns]
# Dropped 99.8% entries from factor data: 20.6% in forward returns computation and 79.2% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha096 error continue
# alpha097 error continue
# Dropped 23.6% entries from factor data: 21.5% in forward returns computation and 2.1% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha098 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.009283  0.084676         -0.109628   -1.991491     0.047253 -0.001525
#
#     IC Kurtosis AlphaName
# 1D      0.15824  alpha098
# alpha098 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha098  1.320645        0.000839   1.287569
# Dropped 100.0% entries from factor data: 22.6% in forward returns computation and 77.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha099 error continue
# alpha100 error continue
# Dropped 0.4% entries from factor data: 0.4% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha101 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.025035  0.13742         -0.182181   -3.471016     0.000581 -0.303736
#
#     IC Kurtosis AlphaName
# 1D     1.061296  alpha101
# alpha101 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha101  2.00349        0.001587   1.706125

# %%
import pandas as pd
SP = pd.read_csv('ALPHA101_SP_tables.csv')
IC = pd.read_csv('ALPHA101_IC_tables.csv')
all = pd.merge(SP,IC,on=['AlphaName'])


# # 筛选表现好的因子
good_factors = all.sort_values(by=["SP","Pro Total"], ascending=False)  
good_factors = good_factors[['AlphaName','SP','Pro Daily Mean','Pro Total','IC Mean','IC Std.','t-stat(IC)']]
# print("表现好的因子：")
# print(good_factors[["AlphaName", "IC Mean", "Risk-Adjusted IC", "t-stat(IC)", "p-value(IC)"]])
good_factors.head(30)
# Out:
#    AlphaName        SP  Pro Daily Mean  Pro Total   IC Mean   IC Std.  \
# 13  alpha017  3.752989        0.003392   3.009050  0.026970  0.113300
# 25  alpha032  3.262577        0.002604   2.428664  0.086298  0.164235
# 10  alpha014  2.670790        0.002284   2.138853  0.020273  0.105821
# 15  alpha019  2.591475        0.002609   1.315521  0.018896  0.173187
# 12  alpha016  2.471248        0.002198   2.059074  0.046205  0.088883
# 21  alpha028  2.107505        0.001839   1.853962 -0.002025  0.098645
# 58  alpha101  2.003490        0.001587   1.706125 -0.025035  0.137420
# 36  alpha044  1.707827        0.001256   1.514702  0.047088  0.090581
# 55  alpha088  1.660327        0.002186   1.817833  0.072985  0.141559
# 0   alpha002  1.641834        0.001175   1.469528  0.020824  0.075278
# 3   alpha006  1.601968        0.001098   1.430698  0.018665  0.102809
# 32  alpha040  1.589855        0.001304   1.519213  0.029324  0.104534
# 22  alpha029  1.566465        0.001325   1.522382  0.012208  0.104653
# 20  alpha026  1.500151        0.001088   1.366930  0.021939  0.093125
# 9   alpha013  1.481941        0.001426   1.529357  0.038473  0.076583
# 43  alpha053  1.470514        0.001365   1.533434  0.026147  0.120543
# 27  alpha034  1.469964        0.001281   1.512166  0.018584  0.118772
# 28  alpha036  1.363756        0.001034   1.164619  0.013435  0.111434
# 57  alpha098  1.320645        0.000839   1.287569 -0.009283  0.084676
# 11  alpha015  1.044644        0.000716   1.242777  0.034623  0.077814
# 35  alpha043  0.966406        0.000731   1.180196  0.013908  0.107530
# 19  alpha025  0.928254        0.000860   1.274416  0.030718  0.113479
# 30  alpha038  0.927248        0.000881   1.288688  0.031689  0.148411
# 26  alpha033  0.901099        0.000993   1.321366  0.035163  0.179025
# 45  alpha055  0.816282        0.000552   1.176636  0.026403  0.072450
# 53  alpha084  0.809772        0.000642   1.152639 -0.013130  0.112651
# 4   alpha008  0.774594        0.000763   1.226174  0.014204  0.105760
# 37  alpha045  0.463252        0.000340   1.085459  0.009554  0.086172
# 2   alpha005  0.447009        0.000356   1.089036  0.008837  0.114404
# 24  alpha031  0.423829        0.000295   1.073586  0.011983  0.096881
#
#     t-stat(IC)
# 13    4.389304
# 25    9.928210
# 10    3.604601
# 15    1.159810
# 12         NaN
# 21   -0.391021
# 58   -3.471016
# 36    9.849631
# 55         NaN
# 0     5.219460
# 3     3.415940
# 32    5.278055
# 22    2.188675
# 20         NaN
# 9          NaN
# 43    4.081100
# 27    2.977083
# 28    1.543953
# 57   -1.991491
# 11         NaN
# 35         NaN
# 19    5.020531
# 30    4.017374
# 26    3.742231
# 45    6.788639
# 53         NaN
# 4     2.505383
# 37    2.041459
# 2     1.453314
# 24    2.294139
