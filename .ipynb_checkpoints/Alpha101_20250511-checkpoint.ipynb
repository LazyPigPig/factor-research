# %% [markdown]
# ### 1. Load History OHCLV
#
# create a new terminal and
#
# Download-data:
# `
# freqtrade download-data --config user_data/config.json --timeframe 15m --timerange 20240101-20250101
# `
#
# File-like:
# `
# BTC_USDT-15m.feather
# `

# %%
import pandas as pd 
import os
import re
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.append('./')

file_path = '/usr/local/services/freqtrade-grid/user_data/data/binance/futures'
time_frame = '1d'

def extract_coin_symbols(directory):
    coin_list = []
    pattern = re.compile(r'(.+?)_USDT-1d-futures\.feather$')

    for filename in os.listdir(directory):
        match = pattern.match(filename)
        if match:
            coin_symbol = (match.group(1)+':USDT').replace('_','/')
            coin_list.append(coin_symbol)
    
    return coin_list


if os.path.exists(file_path) and os.path.isdir(file_path):
    coins = extract_coin_symbols(file_path)
print(len(coins))
# Out:
# 393

# %% [markdown]
# ### 2. Pair Filter

# %%
top50 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT"
]

top100 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT","ATOM/USDT:USDT","ALGO/USDT:USDT","JUP/USDT:USDT","TIA/USDT:USDT","VIRTUAL/USDT:USDT","INJ/USDT:USDT","QNT/USDT:USDT","STX/USDT:USDT","S/USDT:USDT","DEXE/USDT:USDT","OP/USDT:USDT","FARTCOIN/USDT:USDT","IP/USDT:USDT","FORM/USDT:USDT","SEI/USDT:USDT","A/USDT:USDT","SPX/USDT:USDT","IMX/USDT:USDT","WIF/USDT:USDT","GRT/USDT:USDT","CRV/USDT:USDT","LDO/USDT:USDT","ZEC/USDT:USDT","ENS/USDT:USDT","JASMY/USDT:USDT","THETA/USDT:USDT","CAKE/USDT:USDT","GALA/USDT:USDT","WAL/USDT:USDT","SAND/USDT:USDT","IOTA/USDT:USDT","PYTH/USDT:USDT","PENGU/USDT:USDT","BSV/USDT:USDT","PENDLE/USDT:USDT","KAIA/USDT:USDT"
]

top150 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT","ATOM/USDT:USDT","ALGO/USDT:USDT","JUP/USDT:USDT","TIA/USDT:USDT","VIRTUAL/USDT:USDT","INJ/USDT:USDT","QNT/USDT:USDT","STX/USDT:USDT","S/USDT:USDT","DEXE/USDT:USDT","OP/USDT:USDT","FARTCOIN/USDT:USDT","IP/USDT:USDT","FORM/USDT:USDT","SEI/USDT:USDT","A/USDT:USDT","SPX/USDT:USDT","IMX/USDT:USDT","WIF/USDT:USDT","GRT/USDT:USDT","CRV/USDT:USDT","LDO/USDT:USDT","ZEC/USDT:USDT","ENS/USDT:USDT","JASMY/USDT:USDT","THETA/USDT:USDT","CAKE/USDT:USDT","GALA/USDT:USDT","WAL/USDT:USDT","SAND/USDT:USDT","IOTA/USDT:USDT","PYTH/USDT:USDT","PENGU/USDT:USDT","BSV/USDT:USDT","PENDLE/USDT:USDT","KAIA/USDT:USDT","XTZ/USDT:USDT","RUNE/USDT:USDT","FLOW/USDT:USDT","BRETT/USDT:USDT","ZKJ/USDT:USDT","JTO/USDT:USDT","XCN/USDT:USDT","MANA/USDT:USDT","APE/USDT:USDT","KAITO/USDT:USDT","DEEP/USDT:USDT","ATH/USDT:USDT","GRASS/USDT:USDT","EIGEN/USDT:USDT","EGLD/USDT:USDT","DYDX/USDT:USDT","AR/USDT:USDT","AERO/USDT:USDT","STRK/USDT:USDT","KAVA/USDT:USDT","NEO/USDT:USDT","AXS/USDT:USDT","RSR/USDT:USDT","SUPER/USDT:USDT","LPT/USDT:USDT","ETHFI/USDT:USDT","W/USDT:USDT","CFX/USDT:USDT","SYRUP/USDT:USDT","CHZ/USDT:USDT","MOVE/USDT:USDT","POPCAT/USDT:USDT","MORPHO/USDT:USDT","COMP/USDT:USDT","SAFE/USDT:USDT","SUN/USDT:USDT"
]

top200 = [
"BTC/USDT:USDT","ETH/USDT:USDT","XRP/USDT:USDT","BNB/USDT:USDT","SOL/USDT:USDT","DOGE/USDT:USDT","TRX/USDT:USDT","ADA/USDT:USDT","SUI/USDT:USDT","HYPE/USDT:USDT","LINK/USDT:USDT","AVAX/USDT:USDT","XLM/USDT:USDT","TON/USDT:USDT","BCH/USDT:USDT","HBAR/USDT:USDT","LTC/USDT:USDT","DOT/USDT:USDT","XMR/USDT:USDT","UNI/USDT:USDT","AAVE/USDT:USDT","TAO/USDT:USDT","NEAR/USDT:USDT","APT/USDT:USDT","ONDO/USDT:USDT","ICP/USDT:USDT","ETC/USDT:USDT","KAS/USDT:USDT","POL/USDT:USDT","TRUMP/USDT:USDT","VET/USDT:USDT","RENDER/USDT:USDT","ENA/USDT:USDT","FET/USDT:USDT","WLD/USDT:USDT","ARB/USDT:USDT","FIL/USDT:USDT","ATOM/USDT:USDT","ALGO/USDT:USDT","JUP/USDT:USDT","TIA/USDT:USDT","VIRTUAL/USDT:USDT","INJ/USDT:USDT","QNT/USDT:USDT","STX/USDT:USDT","S/USDT:USDT","DEXE/USDT:USDT","OP/USDT:USDT","FARTCOIN/USDT:USDT","IP/USDT:USDT","FORM/USDT:USDT","SEI/USDT:USDT","A/USDT:USDT","SPX/USDT:USDT","IMX/USDT:USDT","WIF/USDT:USDT","GRT/USDT:USDT","CRV/USDT:USDT","LDO/USDT:USDT","ZEC/USDT:USDT","ENS/USDT:USDT","JASMY/USDT:USDT","THETA/USDT:USDT","CAKE/USDT:USDT","GALA/USDT:USDT","WAL/USDT:USDT","SAND/USDT:USDT","IOTA/USDT:USDT","PYTH/USDT:USDT","PENGU/USDT:USDT","BSV/USDT:USDT","PENDLE/USDT:USDT","KAIA/USDT:USDT","XTZ/USDT:USDT","RUNE/USDT:USDT","FLOW/USDT:USDT","BRETT/USDT:USDT","ZKJ/USDT:USDT","JTO/USDT:USDT","XCN/USDT:USDT","MANA/USDT:USDT","APE/USDT:USDT","KAITO/USDT:USDT","DEEP/USDT:USDT","ATH/USDT:USDT","GRASS/USDT:USDT","EIGEN/USDT:USDT","EGLD/USDT:USDT","DYDX/USDT:USDT","AR/USDT:USDT","AERO/USDT:USDT","STRK/USDT:USDT","KAVA/USDT:USDT","NEO/USDT:USDT","AXS/USDT:USDT","RSR/USDT:USDT","SUPER/USDT:USDT","LPT/USDT:USDT","ETHFI/USDT:USDT","W/USDT:USDT","CFX/USDT:USDT","SYRUP/USDT:USDT","CHZ/USDT:USDT","MOVE/USDT:USDT","POPCAT/USDT:USDT","MORPHO/USDT:USDT","COMP/USDT:USDT","SAFE/USDT:USDT","SUN/USDT:USDT","TWT/USDT:USDT","JST/USDT:USDT","AKT/USDT:USDT","OM/USDT:USDT","AXL/USDT:USDT","TURBO/USDT:USDT","BERA/USDT:USDT","1INCH/USDT:USDT","MEW/USDT:USDT","MINA/USDT:USDT","KSM/USDT:USDT","AI16Z/USDT:USDT","DASH/USDT:USDT","PNUT/USDT:USDT","ZRO/USDT:USDT","NXPC/USDT:USDT","SFP/USDT:USDT","NOT/USDT:USDT","SNX/USDT:USDT","GLM/USDT:USDT","ROSE/USDT:USDT","ZIL/USDT:USDT","MOCA/USDT:USDT","MASK/USDT:USDT","BLUR/USDT:USDT","QTUM/USDT:USDT","CKB/USDT:USDT","MOODENG/USDT:USDT","ASTR/USDT:USDT","ZK/USDT:USDT","ZRX/USDT:USDT","GAS/USDT:USDT","ORDI/USDT:USDT","BAT/USDT:USDT","VANA/USDT:USDT","ACH/USDT:USDT"
]

target_coins = top200
# print(target_coins)

# %% [markdown]
# ### 3. Load History OHLCV

# %%
def extract_coin_data(directory):
    coin_list = {}
    symbols = []
    pattern = re.compile(r'(.+?)_USDT-1d-futures\.feather$')

    for filename in os.listdir(directory):
        match = pattern.match(filename)
        if match:
            coin_symbol = (match.group(1)+':USDT').replace('_','/')
            if coin_symbol in target_coins: 
                df = pd.read_feather(f'{directory}/{filename}')
                df = df.reset_index(drop=True)
                if len(df) > 0 :
                    coin_list[coin_symbol] = df
                    symbols.append(coin_symbol)
    
    return coin_list,symbols

if os.path.exists(file_path) and os.path.isdir(file_path):
    coins,symbols = extract_coin_data(file_path)
print(len(coins))
# Out:
# 139

# %% [markdown]
# ### 3. History Data Transform

# %%
import pandas as pd
close_dfs = []
open_dfs = []
high_dfs = []
low_dfs = []
volume_dfs = []


for symbol, df in coins.items():
    
    temp_df = df[['date', 'close']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    close_dfs.append(temp_df)



    temp_df = df[['date', 'open']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    open_dfs.append(temp_df)


    temp_df = df[['date', 'high']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    high_dfs.append(temp_df)
    

    temp_df = df[['date', 'low']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    low_dfs.append(temp_df)

    temp_df = df[['date', 'volume']].copy()
    temp_df['date'] = pd.to_datetime(temp_df['date'])
    temp_df = temp_df.set_index('date')  # 将date设为索引
    # temp_df.index = temp_df.index.tz_localize(None)
    temp_df.columns = [symbol]  
    volume_dfs.append(temp_df)



close = pd.concat(close_dfs, axis=1)
open = pd.concat(open_dfs, axis=1)
high = pd.concat(high_dfs, axis=1)
low = pd.concat(low_dfs, axis=1)
volume = pd.concat(volume_dfs, axis=1)
amount = close.mul(volume, fill_value=1)

# %% [markdown]
# ### 4. OHLCV Filter

# %%
start_time = '2023-01-01'
end_time = '2025-06-01'
close_filter = close[(close.index > start_time) & (close.index < end_time)]
open_filter = open[(open.index > start_time) & (open.index < end_time)]
high_filter = high[(high.index > start_time) & (high.index < end_time)]
low_filter = low[(low.index > start_time) & (low.index < end_time)]
volume_filter = volume[(volume.index > start_time) & (volume.index < end_time)]
amount_filter = amount[(amount.index > start_time) & (amount.index < end_time)]

import matplotlib.pyplot as plt
_, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 12))
high_norm = high_filter/high_filter.bfill().iloc[0] 
close_norm = close_filter/close_filter.bfill().iloc[0] 
high_norm.mean(axis=1).plot(ax=ax1, figsize=(15,6),grid=True)
close_norm.mean(axis=1).plot(ax=ax2, figsize=(15,6),grid=True);

# %% [markdown]
# ### 5. Define Factor

# %%
# Factor in WorldQuant 101
import Alpha101 as alpha101

df_data = {
    'open' : open_filter,
    'close' : close_filter,
    'high' : high_filter,
    'low' : low_filter,
    'volume' : volume_filter, 
}

alpha_all_in_one = alpha101.Alphas101(df_data)
alpha_list = [f"alpha{num:03d}" for num in range(1, 102)]

# %% [markdown]
# ### 6. Data transfrom and process

# %%
import alphalens.utils as utils
import alphalens.tears as tears
import alphalens.performance as perf
import alphalens.plotting as plot
import numpy as np

IC_tables = []
SP_tables = []


for alpha_name in alpha_list:
    try:
        method = getattr(alpha_all_in_one, alpha_name)
        single_alpha = method() 
        factor = single_alpha.stack()
        factor.index.names = ['date', 'asset']
        factor = factor.dropna()  # 清理缺失值
        price = close_filter
    
        factor_data = utils.get_clean_factor_and_forward_returns(
            factor=factor,
            prices=price,
            periods=(1,),  
            quantiles = 5
        )
        
        IC = perf.factor_information_coefficient(factor_data)
        IC_table = plot.plot_information_table(IC,return_df=True)
        IC_table['AlphaName'] = alpha_name
        IC_tables.append(IC_table)
        print(f'{alpha_name} done \n {IC_table}')



        mean_return_by_q, _ = perf.mean_return_by_quantile(
            factor_data,
            by_date=True, 
            demeaned=False,
            group_adjust=False
        )
        top_quantile_daily = mean_return_by_q.loc[5]  # 最高分组每日收益
        bottom_quantile_daily = mean_return_by_q.loc[1]  # 最低分组每日收益
        long_short_daily = top_quantile_daily - bottom_quantile_daily # 计算 Long-Short 组合（最高减最低）
        long_short_cumulative = perf.cumulative_returns(long_short_daily)
        mean_return = long_short_daily.mean()
        std_dev = long_short_daily.std()
        sharpe_ratio = (mean_return) / std_dev * np.sqrt(365)
        SP_table = pd.DataFrame([{
                    "AlphaName":alpha_name,
                    "SP":float(sharpe_ratio),
                    "Pro Daily Mean":float(mean_return),
                    "Pro Total":float(long_short_cumulative.iloc[-1])
                }])
        print(f'{alpha_name} done \n {SP_table}')
        SP_tables.append(SP_table)

       
        
        
    except:
        print(f'{alpha_name} error continue')
    

if len(IC_tables) > 0 :
    IC_df = pd.concat(IC_tables)
    IC_df.to_csv('ALPHA101_IC_tables_top200.csv')

if len(SP_tables) > 0 :
    SP_df = pd.concat(SP_tables)
    SP_df.to_csv('ALPHA101_SP_tables_top200.csv')
# Out:
# Dropped 100.0% entries from factor data: 0.2% in forward returns computation and 99.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha001 error continue
# Dropped 29.5% entries from factor data: 29.1% in forward returns computation and 0.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha002 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.020432  0.110992          0.184087    5.439137  6.956518e-08  0.038416
#
#     IC Kurtosis AlphaName
# 1D    -0.000327  alpha002
# alpha002 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha002 -0.095639       -0.000089   0.806151
# Dropped 61.4% entries from factor data: 29.1% in forward returns computation and 32.3% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha003 error continue
# Dropped 100.0% entries from factor data: 0.2% in forward returns computation and 99.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha004 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha005 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.023397  0.136095          0.171914     5.07366  4.771628e-07  0.019579
#
#     IC Kurtosis AlphaName
# 1D     0.085087  alpha005
# alpha005 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha005 -0.290976       -0.000353   0.580944
# Dropped 29.6% entries from factor data: 29.1% in forward returns computation and 0.5% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha006 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.014059  0.132414          0.106173    3.133465     0.001785 -0.071586
#
#     IC Kurtosis AlphaName
# 1D     0.315745  alpha006
# alpha006 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha006  0.391558        0.000504   1.193131
# Dropped 95.0% entries from factor data: 0.2% in forward returns computation and 94.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha007 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha008 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.016077  0.129478          0.124164    3.651785     0.000276  0.137359
#
#     IC Kurtosis AlphaName
# 1D      0.30293  alpha008
# alpha008 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha008 -0.200612       -0.000213   0.695094
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha009 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.014941  0.135475           0.11029    3.269865     0.001118  0.046021
#
#     IC Kurtosis AlphaName
# 1D     0.062484  alpha009
# alpha009 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha009 -0.814497        -0.00097   0.337589
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha010 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.010984  0.133795          0.082093     2.43389     0.015136  0.066484
#
#     IC Kurtosis AlphaName
# 1D     0.032112  alpha010
# alpha010 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha010 -0.289312       -0.000346   0.583884
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha011 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.000056  0.137496         -0.000409   -0.012103     0.990346  0.004234
#
#     IC Kurtosis AlphaName
# 1D    -0.118502  alpha011
# alpha011 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha011 -0.170469       -0.000217   0.638453
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha012 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.015471  0.125379          0.123391    3.658302     0.000269  0.047152
#
#     IC Kurtosis AlphaName
# 1D      0.18704  alpha012
# alpha012 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha012  0.611264        0.000625   1.461756
# Dropped 60.1% entries from factor data: 0.2% in forward returns computation and 59.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha013 error continue
# Dropped 0.5% entries from factor data: 0.2% in forward returns computation and 0.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha014 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.016607  0.138755          0.119688    3.532321     0.000434 -0.046589
#
#     IC Kurtosis AlphaName
# 1D     0.415302  alpha014
# alpha014 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha014  0.347364         0.00044   1.135646
# Dropped 46.2% entries from factor data: 29.0% in forward returns computation and 17.1% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha015 error continue
# Dropped 56.6% entries from factor data: 0.2% in forward returns computation and 56.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha016 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha017 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.025798  0.148496          0.173726    5.085741  4.500480e-07  0.131614
#
#     IC Kurtosis AlphaName
# 1D     0.282275  alpha017
# alpha017 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha017  0.324051        0.000378   1.116268
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha018 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.000334  0.148399          0.002249    0.066558     0.946949  0.124809
#
#     IC Kurtosis AlphaName
# 1D     0.132951  alpha018
# alpha018 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha018 -0.013776       -0.000016   0.800117
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha019 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.028334  0.173343          0.163454    4.102667     0.000046 -0.051319
#
#     IC Kurtosis AlphaName
# 1D    -0.011753  alpha019
# alpha019 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha019 -0.000262   -3.468501e-07   0.814744
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha020 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.010184  0.121327          0.083934    2.488482     0.013013 -0.180266
#
#     IC Kurtosis AlphaName
# 1D     0.199905  alpha020
# alpha020 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha020 -0.49426       -0.000531   0.520337
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha021 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha022 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.000038  0.130449           0.00029    0.008512     0.993211  0.134359
#
#     IC Kurtosis AlphaName
# 1D    -0.112562  alpha022
# alpha022 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha022 -0.835223       -0.000828   0.420088
# Dropped 85.2% entries from factor data: 29.1% in forward returns computation and 56.1% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha023 error continue
# Dropped 4.1% entries from factor data: 0.2% in forward returns computation and 4.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha024 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.008915  0.142555          0.062538         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha024
# alpha024 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha024 -0.16615       -0.000191   0.694244
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha025 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.027229  0.142959          0.190466    5.588809  3.069373e-08  0.044442
#
#     IC Kurtosis AlphaName
# 1D     0.058348  alpha025
# alpha025 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha025  1.004105        0.001227   2.274399
# Dropped 33.4% entries from factor data: 29.0% in forward returns computation and 4.4% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha026 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.021466  0.123075          0.174416         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha026
# alpha026 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha026 -0.515207       -0.000575   0.516286
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha027 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha028 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.003372  0.137201         -0.024577   -0.729059      0.46616 -0.019713
#
#     IC Kurtosis AlphaName
# 1D     0.123037  alpha028
# alpha028 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha028  1.062593        0.001288   2.455126
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha029 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.017153  0.13157           0.13037     3.84315      0.00013 -0.070129
#
#     IC Kurtosis AlphaName
# 1D     0.068805  alpha029
# alpha029 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha029  0.502817        0.000554   1.333161
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha030 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.013659  0.133062          0.102653    3.012128      0.00267 -0.02413
#
#     IC Kurtosis AlphaName
# 1D    -0.074199  alpha030
# alpha030 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha030  0.701657        0.000841   1.645673
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha031 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.014937  0.128812          0.115961    3.402613     0.000698  -0.0183
#
#     IC Kurtosis AlphaName
# 1D    -0.011888  alpha031
# alpha031 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha031  0.955897        0.001003   1.999532
# Dropped 0.1% entries from factor data: 0.1% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha032 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)  IC Skew  \
# 1D  0.028019  0.128396          0.218223    6.451445  1.833743e-10 -0.16923
#
#     IC Kurtosis AlphaName
# 1D     0.215135  alpha032
# alpha032 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha032  2.357695        0.002501   7.415547
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha033 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.036067  0.189392          0.190435    5.649211  2.176762e-08  0.095216
#
#     IC Kurtosis AlphaName
# 1D     0.122115  alpha033
# alpha033 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha033 -0.401039       -0.000686   0.338918
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha034 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.017137  0.140889          0.121633    3.606164     0.000328  0.00248
#
#     IC Kurtosis AlphaName
# 1D    -0.182787  alpha034
# alpha034 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha034 -0.283372       -0.000326   0.606144
# Dropped 43.3% entries from factor data: 0.2% in forward returns computation and 43.1% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha035 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha036 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.025615  0.138314          0.185195    4.832852     0.000002  0.041281
#
#     IC Kurtosis AlphaName
# 1D    -0.035184  alpha036
# alpha036 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha036  0.436368        0.000479   1.191654
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha037 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.010026  0.143679           0.06978    2.070015     0.038743  0.096618
#
#     IC Kurtosis AlphaName
# 1D    -0.131536  alpha037
# alpha037 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha037  0.574569        0.000691   1.455565
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha038 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.034209  0.163164          0.209659    6.187613  9.395123e-10  0.007137
#
#     IC Kurtosis AlphaName
# 1D     0.128099  alpha038
# alpha038 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha038 -0.259594       -0.000359   0.539799
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha039 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.028384  0.151695          0.187114    4.696515     0.000003 -0.045236
#
#     IC Kurtosis AlphaName
# 1D    -0.030667  alpha039
# alpha039 done
#    AlphaName       SP  Pro Daily Mean  Pro Total
# 0  alpha039  0.02174        0.000026   0.858356
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha040 done
#      IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.02208  0.13584          0.162546    4.797171     0.000002 -0.024155
#
#     IC Kurtosis AlphaName
# 1D    -0.049182  alpha040
# alpha040 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha040  0.702354        0.000793   1.627723
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha041 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.011025  0.138253          0.079747     2.36567     0.018214  0.08434
#
#     IC Kurtosis AlphaName
# 1D     0.146555  alpha041
# alpha041 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha041  0.161102        0.000193   0.940838
# Dropped 1.4% entries from factor data: 0.2% in forward returns computation and 1.2% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha042 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D -0.001653  0.16215         -0.010192         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha042
# alpha042 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha042  0.871281        0.001203    2.11155
# Dropped 23.2% entries from factor data: 0.2% in forward returns computation and 23.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha043 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.003496  0.136273          0.025655         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha043
# alpha043 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha043  0.264604        0.000289   1.047717
# Dropped 29.3% entries from factor data: 29.1% in forward returns computation and 0.2% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha044 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.02927  0.120576           0.24275    7.184757  1.441187e-12 -0.089923
#
#     IC Kurtosis AlphaName
# 1D    -0.093285  alpha044
# alpha044 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha044 -0.448916         -0.0005   0.528548
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha045 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.012818  0.125326          0.102276    2.992333     0.002848  0.031277
#
#     IC Kurtosis AlphaName
# 1D     0.104407  alpha045
# alpha045 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha045  0.101741        0.000096   0.943889
# Dropped 94.1% entries from factor data: 0.2% in forward returns computation and 94.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha046 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha047 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D -0.027724  0.149811          -0.18506   -5.430165  7.329375e-08  0.159286
#
#     IC Kurtosis AlphaName
# 1D    -0.237598  alpha047
# alpha047 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha047 -0.006976        -0.00001    0.73382
# alpha048 error continue
# Dropped 37.5% entries from factor data: 0.2% in forward returns computation and 37.3% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha049 error continue
# Dropped 65.9% entries from factor data: 29.0% in forward returns computation and 36.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha050 error continue
# Dropped 45.2% entries from factor data: 0.2% in forward returns computation and 45.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha051 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha052 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.013165  0.150712          0.087349    2.209781     0.027474 -0.140476
#
#     IC Kurtosis AlphaName
# 1D    -0.247523  alpha052
# alpha052 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha052  0.940557        0.001049   1.695825
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha053 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.01203  0.142879          0.084196    2.484851     0.013148  0.111946
#
#     IC Kurtosis AlphaName
# 1D     0.269893  alpha053
# alpha053 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha053 -0.347908       -0.000412   0.558098
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha054 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.01518  0.155905         -0.097369   -2.888436     0.003967  0.080917
#
#     IC Kurtosis AlphaName
# 1D    -0.107794  alpha054
# alpha054 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha054  0.174154        0.000239   0.914493
# Dropped 30.0% entries from factor data: 29.1% in forward returns computation and 0.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha055 done
#      IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)   p-value(IC)   IC Skew  \
# 1D  0.02466  0.112909          0.218404    6.419744  2.250557e-10  0.110339
#
#     IC Kurtosis AlphaName
# 1D      0.23907  alpha055
# alpha055 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha055  0.076656        0.000079   0.905873
# alpha056 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha057 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.006207  0.138998          0.044655    1.301911       0.1933  0.096919
#
#     IC Kurtosis AlphaName
# 1D     0.133487  alpha057
# alpha057 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha057 -0.041207       -0.000045   0.802308
# alpha058 error continue
# alpha059 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha060 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.002168  0.152706         -0.014195   -0.418938     0.675365  0.120592
#
#     IC Kurtosis AlphaName
# 1D    -0.073931  alpha060
# alpha060 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha060 -0.422401       -0.000546   0.475856
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha061 error continue
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha062 error continue
# alpha063 error continue
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha064 error continue
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha065 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha066 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.008272  0.113753          0.072717    2.137442     0.032843 -0.037489
#
#     IC Kurtosis AlphaName
# 1D    -0.187563  alpha066
# alpha066 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha066 -0.590666       -0.000632   0.484156
# alpha067 error continue
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha068 error continue
# alpha069 error continue
# alpha070 error continue
# Dropped 99.2% entries from factor data: 0.2% in forward returns computation and 99.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha071 error continue
# Dropped 29.7% entries from factor data: 28.9% in forward returns computation and 0.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha072 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.018168  0.121586          0.149428    4.371872     0.000014  0.050382
#
#     IC Kurtosis AlphaName
# 1D    -0.023848  alpha072
# alpha072 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha072  0.057173        0.000058   0.894608
# Dropped 88.1% entries from factor data: 0.2% in forward returns computation and 87.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha073 error continue
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha074 error continue
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha075 error continue
# alpha076 error continue
# Dropped 1.9% entries from factor data: 0.2% in forward returns computation and 1.7% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha077 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D -0.008115  0.133995         -0.060559   -1.754135     0.079773 -0.163774
#
#     IC Kurtosis AlphaName
# 1D     0.010214  alpha077
# alpha077 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha077  0.233181        0.000229   1.046134
# Dropped 31.1% entries from factor data: 29.1% in forward returns computation and 2.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha078 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D  0.014277  0.124515          0.114662         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha078
# alpha078 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha078  0.331095        0.000366   1.128364
# alpha079 error continue
# alpha080 error continue
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha081 error continue
# alpha082 error continue
# Dropped 0.2% entries from factor data: 0.2% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha083 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.012638  0.13888          0.091002     2.69034     0.007274  0.138429
#
#     IC Kurtosis AlphaName
# 1D     0.222877  alpha083
# alpha083 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha083 -0.348188       -0.000403   0.567358
# Dropped 20.2% entries from factor data: 0.7% in forward returns computation and 19.5% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha084 done
#       IC Mean  IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)  IC Skew  \
# 1D -0.024636  0.13772         -0.178884         NaN          NaN      NaN
#
#     IC Kurtosis AlphaName
# 1D          NaN  alpha084
# alpha084 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha084 -0.707566       -0.000783   0.505387
# Dropped 29.9% entries from factor data: 29.1% in forward returns computation and 0.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
# alpha085 done
#       IC Mean   IC Std.  Risk-Adjusted IC  t-stat(IC)  p-value(IC)   IC Skew  \
# 1D  0.013666  0.119652          0.114216    3.359204     0.000816 -0.044522
#
#     IC Kurtosis AlphaName
# 1D    -0.079961  alpha085
# alpha085 done
#    AlphaName        SP  Pro Daily Mean  Pro Total
# 0  alpha085  0.381785        0.000413   1.189974
# Dropped 100.0% entries from factor data: 29.1% in forward returns computation and 70.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha086 error continue
# alpha087 error continue
# Dropped 87.1% entries from factor data: 0.2% in forward returns computation and 86.9% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha088 error continue
# alpha089 error continue
# alpha090 error continue
# alpha091 error continue
# Dropped 100.0% entries from factor data: 28.2% in forward returns computation and 71.8% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# alpha092 error continue
# alpha093 error continue

# %%
import pandas as pd
SP = pd.read_csv('ALPHA101_SP_tables_top200.csv')
IC = pd.read_csv('ALPHA101_IC_tables_top200.csv')
all = pd.merge(SP,IC,on=['AlphaName'])


# # 筛选表现好的因子
good_factors = all.sort_values(by=["SP","Pro Total"], ascending=False)  
good_factors = good_factors[['AlphaName','SP','Pro Daily Mean','Pro Total','IC Mean','IC Std.','t-stat(IC)']]
# print("表现好的因子：")
# print(good_factors[["AlphaName", "IC Mean", "Risk-Adjusted IC", "t-stat(IC)", "p-value(IC)"]])
good_factors
# Out:
#    AlphaName        SP  Pro Daily Mean  Pro Total   IC Mean   IC Std.  \
# 22  alpha032  7.335139        0.011141  45.402683  0.081665  0.187585
# 28  alpha039  2.746531        0.002646   1.323093  0.018504  0.151378
# 12  alpha019  2.353346        0.002874   1.342217  0.016728  0.167634
# 21  alpha031  2.124712        0.002436   2.133716  0.013200  0.127956
# 18  alpha028  1.921874        0.002226   2.053254  0.002092  0.130029
# 20  alpha030  1.617492        0.001921   1.771902  0.018093  0.130937
# 10  alpha017  1.548273        0.001845   1.713460  0.030224  0.137901
# 16  alpha025  1.464586        0.001705   1.651034  0.023796  0.133522
# 7   alpha012  1.413864        0.001475   1.584937  0.013256  0.112235
# 44  alpha072  1.341202        0.001501   1.538757  0.015767  0.119527
# 50  alpha094  1.219100        0.001570   1.368040 -0.009089  0.140031
# 11  alpha018  1.101333        0.001244   1.438453 -0.006453  0.134792
# 32  alpha043  0.938106        0.001136   1.234157  0.008250  0.131348
# 26  alpha037  0.923861        0.001260   1.390771  0.009335  0.131695
# 34  alpha045  0.868233        0.000797   1.244004  0.005168  0.111285
# 52  alpha101  0.859722        0.001489   1.414108 -0.020448  0.157388
# 49  alpha085  0.857212        0.000958   1.290468  0.006696  0.110114
# 0   alpha002  0.809569        0.000696   1.221214  0.016144  0.101965
# 46  alpha078  0.777488        0.000951   1.240266  0.010931  0.112630
# 19  alpha029  0.758448        0.000822   1.238499  0.016482  0.122168
# 29  alpha040  0.753744        0.000838   1.241906  0.012580  0.129302
# 8   alpha014  0.746946        0.000965   1.263350  0.015986  0.138724
# 24  alpha034  0.607703        0.000718   1.182356  0.022062  0.138423
# 1   alpha005  0.529510        0.000622   1.141324  0.014013  0.130498
# 41  alpha057  0.467026        0.000500   1.102222  0.010035  0.134964
# 3   alpha008  0.451774        0.000492   1.100698  0.012740  0.128711
# 2   alpha006  0.429421        0.000607   1.092407  0.012466  0.129765
# 31  alpha042  0.332609        0.000514   1.033128 -0.015743  0.169980
# 15  alpha024  0.271152        0.000336   1.019555  0.009617  0.136016
# 45  alpha077  0.260655        0.000298   1.020531 -0.011542  0.133879
# 13  alpha020  0.152952        0.000168   0.982016  0.008711  0.113510
# 30  alpha041  0.082373        0.000100   0.941030  0.006854  0.129603
# 25  alpha036  0.080781        0.000087   0.980174  0.023690  0.133357
# 40  alpha055 -0.034552       -0.000033   0.932548  0.019508  0.102544
# 27  alpha038 -0.045414       -0.000066   0.852150  0.022849  0.172491
# 33  alpha044 -0.061625       -0.000069   0.899327  0.026678  0.106801
# 47  alpha083 -0.157387       -0.000181   0.860737  0.006462  0.132360
# 36  alpha049 -0.187258       -0.000317   0.815924  0.024308  0.129653
# 51  alpha098 -0.192109       -0.000209   0.869508 -0.006931  0.114709
# 43  alpha066 -0.401406       -0.000445   0.793649  0.006239  0.105531
# 39  alpha054 -0.405601       -0.000607   0.694067 -0.012194  0.153216
# 35  alpha047 -0.447520       -0.000625   0.714758 -0.025121  0.153956
# 5   alpha010 -0.490804       -0.000624   0.713938  0.010019  0.124022
# 17  alpha026 -0.502044       -0.000556   0.776362  0.017345  0.117564
# 38  alpha053 -0.587293       -0.000680   0.720319  0.016360  0.134234
# 48  alpha084 -0.833011       -0.000967   0.721531 -0.017130  0.136261
# 23  alpha033 -0.916125       -0.001784   0.404115  0.030108  0.198738
# 9   alpha015 -0.932269       -0.001037   0.720752  0.016384  0.092333
# 14  alpha022 -1.006735       -0.000953   0.680898 -0.002444  0.118748
# 37  alpha052 -1.135185       -0.001155   0.847776 -0.000367  0.160095
# 6   alpha011 -1.288308       -0.001869   0.444310 -0.001760  0.136350
# 42  alpha060 -1.468225       -0.002267   0.381736 -0.005851  0.156039
# 4   alpha009 -1.520557       -0.001932   0.444239  0.009750  0.128707
#
#     t-stat(IC)
# 22    8.225693
# 28    1.299392
# 12    1.060787
# 21    1.913280
# 18    0.306566
# 20    2.562906
# 10    4.041307
# 16    3.305411
# 7     2.247133
# 44    2.428690
# 50         NaN
# 11   -0.907139
# 32         NaN
# 26    1.350448
# 34    0.855000
# 52   -2.475320
# 49    1.134322
# 0     2.987304
# 46         NaN
# 19    2.531226
# 29    1.830542
# 8     2.168102
# 24    3.032467
# 1     2.020339
# 41    1.356779
# 3     1.846550
# 2     1.807508
# 31         NaN
# 15         NaN
# 45   -1.547082
# 13    1.460139
# 30    1.007582
# 25    2.274986
# 40    3.543753
# 27    2.492335
# 33    4.732866
# 47    0.922480
# 36         NaN
# 51   -1.097599
# 43    1.101356
# 39   -1.516374
# 35   -3.026352
# 5     1.536993
# 17         NaN
# 38    2.293121
# 48         NaN
# 23    2.886334
# 9          NaN
# 14   -0.381737
# 37   -0.025418
# 6    -0.244969
# 42   -0.705519
# 4     1.441380
